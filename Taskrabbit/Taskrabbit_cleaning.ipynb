# %%
import pandas as pd

# %%
## Reading in a csv of 200 addresses from Detroit, randomly sampled using usps.biglocalnews.org

addresses = pd.read_csv("Detroit_200.csv")
addresses.head()
# Out:
#                       address_full  number   street     city state      zip  \
# 0   748 DUNKIRK DETROIT, MI 48217      748  DUNKIRK  DETROIT    MI  48217.0
# 1  1558 CALVERT DETROIT, MI 48206     1558  CALVERT  DETROIT    MI  48206.0
# 2  8083 NORMILE DETROIT, MI 48204     8083  NORMILE  DETROIT    MI  48204.0
# 3  4054 RICHTON DETROIT, MI 48204     4054  RICHTON  DETROIT    MI  48204.0
# 4   8317 PENROD DETROIT, MI 48228     8317   PENROD  DETROIT    MI  48228.0
#
#    longitude   latitude  statefp  countyfp  tractce  blkgrpce
# 0 -83.150601  42.286192       26       163   524500         2
# 1 -83.100993  42.384252       26       163   531900         1
# 2 -83.158999  42.352950       26       163   535600         4
# 3 -83.130003  42.381745       26       163   530900         2
# 4 -83.220193  42.354021       26       163   546000         2

# %%
## Cleaning the zip column so that it reads as a string without a decimal place

addresses['zip'] = (
    addresses['zip']
    .astype(str)
    .str.replace(".0", "")
)

# %%
addresses.head()
# Out:
#                       address_full  number   street     city state    zip  \
# 0   748 DUNKIRK DETROIT, MI 48217      748  DUNKIRK  DETROIT    MI  48217
# 1  1558 CALVERT DETROIT, MI 48206     1558  CALVERT  DETROIT    MI  48206
# 2  8083 NORMILE DETROIT, MI 48204     8083  NORMILE  DETROIT    MI  48204
# 3  4054 RICHTON DETROIT, MI 48204     4054  RICHTON  DETROIT    MI  48204
# 4   8317 PENROD DETROIT, MI 48228     8317   PENROD  DETROIT    MI  48228
#
#    longitude   latitude  statefp  countyfp  tractce  blkgrpce
# 0 -83.150601  42.286192       26       163   524500         2
# 1 -83.100993  42.384252       26       163   531900         1
# 2 -83.158999  42.352950       26       163   535600         4
# 3 -83.130003  42.381745       26       163   530900         2
# 4 -83.220193  42.354021       26       163   546000         2

# %%
## converting the Detroit address dataframe to a list of dictionaries

address_list = addresses.to_dict('records')
address_list
# Out:
# [{'address_full': '748 DUNKIRK DETROIT, MI 48217 ',
#   'number': 748,
#   'street': 'DUNKIRK',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48217',
#   'longitude': -83.150601,
#   'latitude': 42.286192,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 524500,
#   'blkgrpce': 2},
#  {'address_full': '1558 CALVERT DETROIT, MI 48206 ',
#   'number': 1558,
#   'street': 'CALVERT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.100993,
#   'latitude': 42.384252,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531900,
#   'blkgrpce': 1},
#  {'address_full': '8083 NORMILE DETROIT, MI 48204 ',
#   'number': 8083,
#   'street': 'NORMILE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.158999,
#   'latitude': 42.35295,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535600,
#   'blkgrpce': 4},
#  {'address_full': '4054 RICHTON DETROIT, MI 48204 ',
#   'number': 4054,
#   'street': 'RICHTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.130003,
#   'latitude': 42.381745,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 530900,
#   'blkgrpce': 2},
#  {'address_full': '8317 PENROD DETROIT, MI 48228 ',
#   'number': 8317,
#   'street': 'PENROD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.220193,
#   'latitude': 42.354021,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546000,
#   'blkgrpce': 2},
#  {'address_full': '5286 ALLENDALE DETROIT, MI ',
#   'number': 5286,
#   'street': 'ALLENDALE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': 'nan',
#   'longitude': -83.124704,
#   'latitude': 42.354423,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533600,
#   'blkgrpce': 2},
#  {'address_full': '18422 KELLY RD DETROIT, MI 48224 ',
#   'number': 18422,
#   'street': 'KELLY RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.956106,
#   'latitude': 42.429932,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500700,
#   'blkgrpce': 4},
#  {'address_full': '6238 LINWOOD DETROIT, MI 48208 ',
#   'number': 6238,
#   'street': 'LINWOOD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48208',
#   'longitude': -83.098017,
#   'latitude': 42.358668,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 522300,
#   'blkgrpce': 2},
#  {'address_full': '14358 MONTROSE DETROIT, MI 48227 ',
#   'number': 14358,
#   'street': 'MONTROSE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.20016,
#   'latitude': 42.392622,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542400,
#   'blkgrpce': 1},
#  {'address_full': '21671 GREYDALE CT DETROIT, MI 48219 ',
#   'number': 21671,
#   'street': 'GREYDALE CT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.257121,
#   'latitude': 42.43001,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541000,
#   'blkgrpce': 3},
#  {'address_full': '17177 FENTON DETROIT, MI 48219 ',
#   'number': 17177,
#   'street': 'FENTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.282615,
#   'latitude': 42.415507,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541300,
#   'blkgrpce': 1},
#  {'address_full': '11404 BRAMELL DETROIT, MI 48239 ',
#   'number': 11404,
#   'street': 'BRAMELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48239',
#   'longitude': -83.262891,
#   'latitude': 42.370694,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546301,
#   'blkgrpce': 1},
#  {'address_full': '875 MARLBOROUGH DETROIT, MI 48215 ',
#   'number': 875,
#   'street': 'MARLBOROUGH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.943046,
#   'latitude': 42.37226,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 513200,
#   'blkgrpce': 2},
#  {'address_full': '7217 ST PAUL DETROIT, MI 48214 ',
#   'number': 7217,
#   'street': 'ST PAUL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -83.005856,
#   'latitude': 42.354167,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 515300,
#   'blkgrpce': 1},
#  {'address_full': '460 W CANFIELD 31 DETROIT, MI 48201 ',
#   'number': 460,
#   'street': 'W CANFIELD 31',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48201',
#   'longitude': -83.065538,
#   'latitude': 42.351921,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 520300,
#   'blkgrpce': 2},
#  {'address_full': '5896 ST CLAIR DETROIT, MI 48213 ',
#   'number': 5896,
#   'street': 'ST CLAIR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.998512,
#   'latitude': 42.39315,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505700,
#   'blkgrpce': 5},
#  {'address_full': '425 W SAVANNAH DETROIT, MI 48203 ',
#   'number': 425,
#   'street': 'W SAVANNAH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.107587,
#   'latitude': 42.425101,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509000,
#   'blkgrpce': 3},
#  {'address_full': '1228 NEWPORT DETROIT, MI 48215 ',
#   'number': 1228,
#   'street': 'NEWPORT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.947943,
#   'latitude': 42.375144,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 1},
#  {'address_full': '10231 MENDOTA DETROIT, MI 48204 ',
#   'number': 10231,
#   'street': 'MENDOTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.164779,
#   'latitude': 42.370127,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534400,
#   'blkgrpce': 1},
#  {'address_full': '4616 CHALMERS DETROIT, MI 48215 ',
#   'number': 4616,
#   'street': 'CHALMERS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.956573,
#   'latitude': 42.392534,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502700,
#   'blkgrpce': 1},
#  {'address_full': '20153 RUSSELL DETROIT, MI 48203 ',
#   'number': 20153,
#   'street': 'RUSSELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.091332,
#   'latitude': 42.443146,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507500,
#   'blkgrpce': 1},
#  {'address_full': '15778 WISCONSIN DETROIT, MI 48238 ',
#   'number': 15778,
#   'street': 'WISCONSIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.156374,
#   'latitude': 42.407437,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536300,
#   'blkgrpce': 1},
#  {'address_full': '16249 HUBBELL DETROIT, MI 48235 ',
#   'number': 16249,
#   'street': 'HUBBELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.189658,
#   'latitude': 42.411218,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537600,
#   'blkgrpce': 1},
#  {'address_full': '19185 BELAND DETROIT, MI 48234 ',
#   'number': 19185,
#   'street': 'BELAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.009329,
#   'latitude': 42.435616,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505600,
#   'blkgrpce': 1},
#  {'address_full': '20310 W GRAND RIVER DETROIT, MI 48219 ',
#   'number': 20310,
#   'street': 'W GRAND RIVER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.240979,
#   'latitude': 42.410118,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543200,
#   'blkgrpce': 1},
#  {'address_full': '19921 WARRINGTON DETROIT, MI 48221 ',
#   'number': 19921,
#   'street': 'WARRINGTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.140979,
#   'latitude': 42.439329,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538100,
#   'blkgrpce': 1},
#  {'address_full': '19520 W GRAND RIVER DETROIT, MI 48223 ',
#   'number': 19520,
#   'street': 'W GRAND RIVER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.234145,
#   'latitude': 42.407394,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543000,
#   'blkgrpce': 2},
#  {'address_full': '2257 E KIRBY DETROIT, MI 48211 ',
#   'number': 2257,
#   'street': 'E KIRBY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48211',
#   'longitude': -83.044042,
#   'latitude': 42.368752,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 519100,
#   'blkgrpce': 2},
#  {'address_full': '19190 WESTBROOK DETROIT, MI 48219 ',
#   'number': 19190,
#   'street': 'WESTBROOK',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.251953,
#   'latitude': 42.430695,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541000,
#   'blkgrpce': 3},
#  {'address_full': '17331 ROSELAWN DETROIT, MI 48221 ',
#   'number': 17331,
#   'street': 'ROSELAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.152791,
#   'latitude': 42.419332,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538500,
#   'blkgrpce': 1},
#  {'address_full': '20103 SANTA ROSA DETROIT, MI 48221 ',
#   'number': 20103,
#   'street': 'SANTA ROSA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.144284,
#   'latitude': 42.441431,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539000,
#   'blkgrpce': 2},
#  {'address_full': '734 25TH ST DETROIT, MI 48216 ',
#   'number': 734,
#   'street': '25TH ST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48216',
#   'longitude': -83.082427,
#   'latitude': 42.316335,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 521100,
#   'blkgrpce': 2},
#  {'address_full': '5633 TROWBRIDGE HAMTRAMCK, MI 48212 ',
#   'number': 5633,
#   'street': 'TROWBRIDGE',
#   'city': 'HAMTRAMCK',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.045052,
#   'latitude': 42.404563,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 510600,
#   'blkgrpce': 1},
#  {'address_full': '1268 DRAGOON DETROIT, MI 48209 ',
#   'number': 1268,
#   'street': 'DRAGOON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48209',
#   'longitude': -83.105187,
#   'latitude': 42.311874,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 523200,
#   'blkgrpce': 3},
#  {'address_full': '12767 LORETTO DETROIT, MI 48205 ',
#   'number': 12767,
#   'street': 'LORETTO',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.984765,
#   'latitude': 42.417776,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503900,
#   'blkgrpce': 1},
#  {'address_full': '18717 SORRENTO DETROIT, MI 48235 ',
#   'number': 18717,
#   'street': 'SORRENTO',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.174466,
#   'latitude': 42.429256,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539400,
#   'blkgrpce': 1},
#  {'address_full': '15865 ASHTON DETROIT, MI 48219 ',
#   'number': 15865,
#   'street': 'ASHTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.220116,
#   'latitude': 42.407458,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543000,
#   'blkgrpce': 1},
#  {'address_full': '14804 MADDELEIN DETROIT, MI 48205 ',
#   'number': 14804,
#   'street': 'MADDELEIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.969575,
#   'latitude': 42.435864,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500300,
#   'blkgrpce': 1},
#  {'address_full': '13646 PIEDMONT DETROIT, MI 48223 ',
#   'number': 13646,
#   'street': 'PIEDMONT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.229411,
#   'latitude': 42.386153,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543300,
#   'blkgrpce': 4},
#  {'address_full': '13200 JOY RD DETROIT, MI 48228 ',
#   'number': 13200,
#   'street': 'JOY RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.174111,
#   'latitude': 42.358895,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535000,
#   'blkgrpce': 2},
#  {'address_full': '8061 PLAINVIEW DETROIT, MI 48228 ',
#   'number': 8061,
#   'street': 'PLAINVIEW',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.234806,
#   'latitude': 42.351326,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546000,
#   'blkgrpce': 1},
#  {'address_full': '20486 HULL DETROIT, MI 48203 ',
#   'number': 20486,
#   'street': 'HULL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.088924,
#   'latitude': 42.446104,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507500,
#   'blkgrpce': 1},
#  {'address_full': '24251 PEMBROKE DETROIT, MI 48219 ',
#   'number': 24251,
#   'street': 'PEMBROKE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.28009,
#   'latitude': 42.435822,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541800,
#   'blkgrpce': 1},
#  {'address_full': '2477 BEALS DETROIT, MI 48214 ',
#   'number': 2477,
#   'street': 'BEALS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -83.003303,
#   'latitude': 42.361042,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 515200,
#   'blkgrpce': 1},
#  {'address_full': '20203 MOENART DETROIT, MI 48234 ',
#   'number': 20203,
#   'street': 'MOENART',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.050939,
#   'latitude': 42.444422,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 506700,
#   'blkgrpce': 1},
#  {'address_full': '8371 ROLYAT DETROIT, MI 48234 ',
#   'number': 8371,
#   'street': 'ROLYAT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.018168,
#   'latitude': 42.439878,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505100,
#   'blkgrpce': 3},
#  {'address_full': '12218 PLAINVIEW DETROIT, MI 48228 ',
#   'number': 12218,
#   'street': 'PLAINVIEW',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.234828,
#   'latitude': 42.376731,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 547100,
#   'blkgrpce': 4},
#  {'address_full': '17822 BRUSH DETROIT, MI 48203 ',
#   'number': 17822,
#   'street': 'BRUSH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.097323,
#   'latitude': 42.423658,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509000,
#   'blkgrpce': 4},
#  {'address_full': '15237 E STATE FAIR DETROIT, MI 48205 ',
#   'number': 15237,
#   'street': 'E STATE FAIR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.964897,
#   'latitude': 42.442882,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500200,
#   'blkgrpce': 2},
#  {'address_full': '11803 GREINER DETROIT, MI 48205 ',
#   'number': 11803,
#   'street': 'GREINER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -83.00291,
#   'latitude': 42.427492,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503500,
#   'blkgrpce': 1},
#  {'address_full': '19954 CHERRYLAWN DETROIT, MI 48221 ',
#   'number': 19954,
#   'street': 'CHERRYLAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.155454,
#   'latitude': 42.439464,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539000,
#   'blkgrpce': 1},
#  {'address_full': '15428 COYLE DETROIT, MI 48227 ',
#   'number': 15428,
#   'street': 'COYLE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.193595,
#   'latitude': 42.403935,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537500,
#   'blkgrpce': 1},
#  {'address_full': '19136 JOY RD DETROIT, MI 48228 ',
#   'number': 19136,
#   'street': 'JOY RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.228269,
#   'latitude': 42.357969,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546700,
#   'blkgrpce': 1},
#  {'address_full': '10452 BONITA DETROIT, MI 48224 ',
#   'number': 10452,
#   'street': 'BONITA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.959671,
#   'latitude': 42.413978,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501100,
#   'blkgrpce': 4},
#  {'address_full': '11214 GLENFIELD DETROIT, MI 48213 ',
#   'number': 11214,
#   'street': 'GLENFIELD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.997289,
#   'latitude': 42.408895,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505200,
#   'blkgrpce': 1},
#  {'address_full': '3489 ALGONQUIN DETROIT, MI 48215 ',
#   'number': 3489,
#   'street': 'ALGONQUIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.964562,
#   'latitude': 42.382149,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 2},
#  {'address_full': '9950 LAUDER DETROIT, MI 48227 ',
#   'number': 9950,
#   'street': 'LAUDER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.189462,
#   'latitude': 42.368818,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 1},
#  {'address_full': '17337 PREVOST DETROIT, MI 48235 ',
#   'number': 17337,
#   'street': 'PREVOST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.203987,
#   'latitude': 42.418267,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540400,
#   'blkgrpce': 1},
#  {'address_full': '9911 LAUDER DETROIT, MI 48227 ',
#   'number': 9911,
#   'street': 'LAUDER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.190056,
#   'latitude': 42.368253,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 1},
#  {'address_full': '18559 ST AUBIN DETROIT, MI 48234 ',
#   'number': 18559,
#   'street': 'ST AUBIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.081775,
#   'latitude': 42.429166,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507100,
#   'blkgrpce': 1},
#  {'address_full': '19481 JAMES COUZENS DETROIT, MI 48235 ',
#   'number': 19481,
#   'street': 'JAMES COUZENS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.192127,
#   'latitude': 42.43522,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539700,
#   'blkgrpce': 1},
#  {'address_full': '18606 BELAND DETROIT, MI 48205 ',
#   'number': 18606,
#   'street': 'BELAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -83.009097,
#   'latitude': 42.430909,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505600,
#   'blkgrpce': 2},
#  {'address_full': '22413 LYNDON DETROIT, MI 48223 ',
#   'number': 22413,
#   'street': 'LYNDON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.261864,
#   'latitude': 42.392801,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544100,
#   'blkgrpce': 1},
#  {'address_full': '8092 WISCONSIN DETROIT, MI 48204 ',
#   'number': 8092,
#   'street': 'WISCONSIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.153744,
#   'latitude': 42.353176,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534700,
#   'blkgrpce': 1},
#  {'address_full': '2587 GRAY DETROIT, MI 48215 ',
#   'number': 2587,
#   'street': 'GRAY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.959383,
#   'latitude': 42.378145,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 2},
#  {'address_full': '4875 MARSEILLES DETROIT, MI 48224 ',
#   'number': 4875,
#   'street': 'MARSEILLES',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.921098,
#   'latitude': 42.408445,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501700,
#   'blkgrpce': 2},
#  {'address_full': '4379 LUMLEY DETROIT, MI 48210 ',
#   'number': 4379,
#   'street': 'LUMLEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.13826,
#   'latitude': 42.326746,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 526000,
#   'blkgrpce': 2},
#  {'address_full': '8116 GREENLAWN DETROIT, MI 48204 ',
#   'number': 8116,
#   'street': 'GREENLAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.148428,
#   'latitude': 42.353608,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534800,
#   'blkgrpce': 2},
#  {'address_full': '14156 LAMPHERE DETROIT, MI 48223 ',
#   'number': 14156,
#   'street': 'LAMPHERE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.26109,
#   'latitude': 42.38909,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544800,
#   'blkgrpce': 1},
#  {'address_full': '18924 BENTLER DETROIT, MI 48219 ',
#   'number': 18924,
#   'street': 'BENTLER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.253017,
#   'latitude': 42.426822,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541200,
#   'blkgrpce': 2},
#  {'address_full': '15780 SCHAEFER DETROIT, MI 48227 ',
#   'number': 15780,
#   'street': 'SCHAEFER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.178966,
#   'latitude': 42.407102,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537000,
#   'blkgrpce': 1},
#  {'address_full': '12831 FRANKFORT DETROIT, MI 48213 ',
#   'number': 12831,
#   'street': 'FRANKFORT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.968113,
#   'latitude': 42.393102,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502600,
#   'blkgrpce': 6},
#  {'address_full': '15348 ILENE DETROIT, MI 48238 ',
#   'number': 15348,
#   'street': 'ILENE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.161557,
#   'latitude': 42.403276,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536800,
#   'blkgrpce': 1},
#  {'address_full': '12039 WHITCOMB DETROIT, MI 48227 ',
#   'number': 12039,
#   'street': 'WHITCOMB',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.195757,
#   'latitude': 42.375389,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 2},
#  {'address_full': '19151 DEQUINDRE DETROIT, MI 48234 ',
#   'number': 19151,
#   'street': 'DEQUINDRE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.083209,
#   'latitude': 42.433718,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507400,
#   'blkgrpce': 2},
#  {'address_full': '3426 LIVERNOIS DETROIT, MI 48210 ',
#   'number': 3426,
#   'street': 'LIVERNOIS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.116642,
#   'latitude': 42.326646,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 525900,
#   'blkgrpce': 2},
#  {'address_full': '18251 FITZPATRICK DETROIT, MI 48228 ',
#   'number': 18251,
#   'street': 'FITZPATRICK',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.218607,
#   'latitude': 42.364604,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546700,
#   'blkgrpce': 2},
#  {'address_full': '20183 GODDARD DETROIT, MI 48234 ',
#   'number': 20183,
#   'street': 'GODDARD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.078,
#   'latitude': 42.443768,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 506800,
#   'blkgrpce': 2},
#  {'address_full': '18461 FENMORE DETROIT, MI 48235 ',
#   'number': 18461,
#   'street': 'FENMORE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.218319,
#   'latitude': 42.425733,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540300,
#   'blkgrpce': 1},
#  {'address_full': '14101 WINTHROP DETROIT, MI 48227 ',
#   'number': 14101,
#   'street': 'WINTHROP',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.199533,
#   'latitude': 42.38946,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542400,
#   'blkgrpce': 2},
#  {'address_full': '11174 CHARLEMAGNE DETROIT, MI 48213 ',
#   'number': 11174,
#   'street': 'CHARLEMAGNE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.997203,
#   'latitude': 42.408087,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505200,
#   'blkgrpce': 1},
#  {'address_full': '638 LAWRENCE DETROIT, MI 48202 ',
#   'number': 638,
#   'street': 'LAWRENCE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.091336,
#   'latitude': 42.389863,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 532100,
#   'blkgrpce': 2},
#  {'address_full': '5936 HARDING DETROIT, MI 48213 ',
#   'number': 5936,
#   'street': 'HARDING',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.997664,
#   'latitude': 42.393638,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505700,
#   'blkgrpce': 5},
#  {'address_full': '9525 LITTLEFIELD DETROIT, MI 48228 ',
#   'number': 9525,
#   'street': 'LITTLEFIELD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.175621,
#   'latitude': 42.366324,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535100,
#   'blkgrpce': 2},
#  {'address_full': '470 W LANTZ DETROIT, MI 48203 ',
#   'number': 470,
#   'street': 'W LANTZ',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.108802,
#   'latitude': 42.437233,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 508000,
#   'blkgrpce': 1},
#  {'address_full': '10297 HINDLE DETROIT, MI 48211 ',
#   'number': 10297,
#   'street': 'HINDLE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48211',
#   'longitude': -83.073009,
#   'latitude': 42.394275,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511400,
#   'blkgrpce': 1},
#  {'address_full': '14252 APPOLINE DETROIT, MI 48227 ',
#   'number': 14252,
#   'street': 'APPOLINE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.169727,
#   'latitude': 42.392298,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537200,
#   'blkgrpce': 1},
#  {'address_full': '15701 ROCKDALE DETROIT, MI 48223 ',
#   'number': 15701,
#   'street': 'ROCKDALE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.258581,
#   'latitude': 42.404014,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544200,
#   'blkgrpce': 2},
#  {'address_full': '9241 LONGWORTH DETROIT, MI 48209 ',
#   'number': 9241,
#   'street': 'LONGWORTH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48209',
#   'longitude': -83.133986,
#   'latitude': 42.301357,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 524300,
#   'blkgrpce': 3},
#  {'address_full': '16615 COLLINGHAM DETROIT, MI 48205 ',
#   'number': 16615,
#   'street': 'COLLINGHAM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.948345,
#   'latitude': 42.448683,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500100,
#   'blkgrpce': 2},
#  {'address_full': '19167 HAWTHORNE DETROIT, MI 48203 ',
#   'number': 19167,
#   'street': 'HAWTHORNE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.092929,
#   'latitude': 42.433539,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507400,
#   'blkgrpce': 2},
#  {'address_full': '19662 BLOOM DETROIT, MI 48234 ',
#   'number': 19662,
#   'street': 'BLOOM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.049044,
#   'latitude': 42.439254,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 506600,
#   'blkgrpce': 1},
#  {'address_full': '5760 NOTTINGHAM DETROIT, MI 48224 ',
#   'number': 5760,
#   'street': 'NOTTINGHAM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.952341,
#   'latitude': 42.404955,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501300,
#   'blkgrpce': 1},
#  {'address_full': '8842 HARTWELL DETROIT, MI 48228 ',
#   'number': 8842,
#   'street': 'HARTWELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.175947,
#   'latitude': 42.35932,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535000,
#   'blkgrpce': 2},
#  {'address_full': '3011 BEALS DETROIT, MI 48214 ',
#   'number': 3011,
#   'street': 'BEALS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -83.005258,
#   'latitude': 42.363754,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 515200,
#   'blkgrpce': 2},
#  {'address_full': '20045 RENFREW DETROIT, MI 48221 ',
#   'number': 20045,
#   'street': 'RENFREW',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.135525,
#   'latitude': 42.44107,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538100,
#   'blkgrpce': 2},
#  {'address_full': '9536 ARTESIAN DETROIT, MI 48228 ',
#   'number': 9536,
#   'street': 'ARTESIAN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.22598,
#   'latitude': 42.365491,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 547100,
#   'blkgrpce': 3},
#  {'address_full': '8054 DARWIN DETROIT, MI 48234 ',
#   'number': 8054,
#   'street': 'DARWIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.022451,
#   'latitude': 42.415273,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505700,
#   'blkgrpce': 1},
#  {'address_full': '6310 GRANDMONT DETROIT, MI ',
#   'number': 6310,
#   'street': 'GRANDMONT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': 'nan',
#   'longitude': -83.207941,
#   'latitude': 42.336531,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 545600,
#   'blkgrpce': 1},
#  {'address_full': '12937 SPARLING DETROIT, MI 48212 ',
#   'number': 12937,
#   'street': 'SPARLING',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.045794,
#   'latitude': 42.413781,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511300,
#   'blkgrpce': 2},
#  {'address_full': '14732 METTETAL DETROIT, MI 48227 ',
#   'number': 14732,
#   'street': 'METTETAL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.207265,
#   'latitude': 42.396997,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542300,
#   'blkgrpce': 1},
#  {'address_full': '1709 W GRAND BLVD DETROIT, MI 48210 ',
#   'number': 1709,
#   'street': 'W GRAND BLVD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.111137,
#   'latitude': 42.348806,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 527900,
#   'blkgrpce': 2},
#  {'address_full': '3529 25TH ST DETROIT, MI 48208 ',
#   'number': 3529,
#   'street': '25TH ST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48208',
#   'longitude': -83.095751,
#   'latitude': 42.335031,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 522800,
#   'blkgrpce': 1},
#  {'address_full': '11120 KENMOOR DETROIT, MI 48205 ',
#   'number': 11120,
#   'street': 'KENMOOR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -83.007659,
#   'latitude': 42.416395,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505200,
#   'blkgrpce': 2},
#  {'address_full': '120 SEWARD 43/405 DETROIT, MI 48202 ',
#   'number': 120,
#   'street': 'SEWARD 43/405',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.078883,
#   'latitude': 42.374512,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533900,
#   'blkgrpce': 1},
#  {'address_full': '3038 CLAIRMOUNT DETROIT, MI 48206 ',
#   'number': 3038,
#   'street': 'CLAIRMOUNT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.113662,
#   'latitude': 42.371062,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533200,
#   'blkgrpce': 2},
#  {'address_full': '2235 CRANE DETROIT, MI 48214 ',
#   'number': 2235,
#   'street': 'CRANE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -82.993126,
#   'latitude': 42.36282,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 513800,
#   'blkgrpce': 2},
#  {'address_full': '14591 CRUSE DETROIT, MI 48227 ',
#   'number': 14591,
#   'street': 'CRUSE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.183468,
#   'latitude': 42.396023,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537100,
#   'blkgrpce': 2},
#  {'address_full': '12087 FORRER DETROIT, MI 48227 ',
#   'number': 12087,
#   'street': 'FORRER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.201647,
#   'latitude': 42.375951,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 545100,
#   'blkgrpce': 2},
#  {'address_full': '18199 HULL DETROIT, MI 48203 ',
#   'number': 18199,
#   'street': 'HULL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.089128,
#   'latitude': 42.427853,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507300,
#   'blkgrpce': 1},
#  {'address_full': '9304 CHALMERS DETROIT, MI 48213 ',
#   'number': 9304,
#   'street': 'CHALMERS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.966002,
#   'latitude': 42.407466,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 504100,
#   'blkgrpce': 1},
#  {'address_full': '14040 GREENFIELD DETROIT, MI 48227 ',
#   'number': 14040,
#   'street': 'GREENFIELD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.197164,
#   'latitude': 42.389126,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537300,
#   'blkgrpce': 1},
#  {'address_full': '14541 RUTLAND DETROIT, MI 48227 ',
#   'number': 14541,
#   'street': 'RUTLAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.21392,
#   'latitude': 42.394633,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542500,
#   'blkgrpce': 2},
#  {'address_full': '3542 DICKERSON DETROIT, MI 48215 ',
#   'number': 3542,
#   'street': 'DICKERSON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.961224,
#   'latitude': 42.384166,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 2},
#  {'address_full': '15000 MANNING DETROIT, MI 48205 ',
#   'number': 15000,
#   'street': 'MANNING',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.966831,
#   'latitude': 42.44072,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500300,
#   'blkgrpce': 1},
#  {'address_full': '8411 SIEBERT DETROIT, MI 48234 ',
#   'number': 8411,
#   'street': 'SIEBERT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.017094,
#   'latitude': 42.40582,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505700,
#   'blkgrpce': 1},
#  {'address_full': '14336 DACOSTA DETROIT, MI 48223 ',
#   'number': 14336,
#   'street': 'DACOSTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.259872,
#   'latitude': 42.391212,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544800,
#   'blkgrpce': 1},
#  {'address_full': '9222 KENSINGTON DETROIT, MI 48224 ',
#   'number': 9222,
#   'street': 'KENSINGTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.9438,
#   'latitude': 42.415067,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501000,
#   'blkgrpce': 1},
#  {'address_full': '3061 COPLIN DETROIT, MI 48215 ',
#   'number': 3061,
#   'street': 'COPLIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.957569,
#   'latitude': 42.383025,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 2},
#  {'address_full': '3456 CADILLAC DETROIT, MI 48214 ',
#   'number': 3456,
#   'street': 'CADILLAC',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -82.989475,
#   'latitude': 42.372294,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 513900,
#   'blkgrpce': 1},
#  {'address_full': '18262 STAHELIN DETROIT, MI 48219 ',
#   'number': 18262,
#   'street': 'STAHELIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.226982,
#   'latitude': 42.423611,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540500,
#   'blkgrpce': 2},
#  {'address_full': '15335 INDIANA DETROIT, MI 48238 ',
#   'number': 15335,
#   'street': 'INDIANA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.15784,
#   'latitude': 42.403123,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536300,
#   'blkgrpce': 2},
#  {'address_full': '8801 MONICA DETROIT, MI 48204 ',
#   'number': 8801,
#   'street': 'MONICA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.140936,
#   'latitude': 42.359427,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534800,
#   'blkgrpce': 3},
#  {'address_full': '3205 WHITNEY DETROIT, MI 48206 ',
#   'number': 3205,
#   'street': 'WHITNEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.107709,
#   'latitude': 42.361328,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533300,
#   'blkgrpce': 1},
#  {'address_full': '2123 MCPHERSON DETROIT, MI 48212 ',
#   'number': 2123,
#   'street': 'MCPHERSON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.069886,
#   'latitude': 42.405342,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509100,
#   'blkgrpce': 2},
#  {'address_full': '8557 DEARBORN DETROIT, MI 48209 ',
#   'number': 8557,
#   'street': 'DEARBORN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48209',
#   'longitude': -83.119465,
#   'latitude': 42.290939,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 524600,
#   'blkgrpce': 1},
#  {'address_full': '9953 ARCHDALE DETROIT, MI 48227 ',
#   'number': 9953,
#   'street': 'ARCHDALE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.215865,
#   'latitude': 42.368347,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 545200,
#   'blkgrpce': 2},
#  {'address_full': '15369 MENDOTA DETROIT, MI 48238 ',
#   'number': 15369,
#   'street': 'MENDOTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.165526,
#   'latitude': 42.403461,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536800,
#   'blkgrpce': 1},
#  {'address_full': '16885 SUNDERLAND RD DETROIT, MI 48219 ',
#   'number': 16885,
#   'street': 'SUNDERLAND RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.228185,
#   'latitude': 42.414771,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543100,
#   'blkgrpce': 1},
#  {'address_full': '2340 GLYNN CT DETROIT, MI 48206 ',
#   'number': 2340,
#   'street': 'GLYNN CT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.10925,
#   'latitude': 42.380225,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531300,
#   'blkgrpce': 1},
#  {'address_full': '16825 MONTE VISTA DETROIT, MI 48221 ',
#   'number': 16825,
#   'street': 'MONTE VISTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.168115,
#   'latitude': 42.414719,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536200,
#   'blkgrpce': 2},
#  {'address_full': '16150 LENORE DETROIT, MI 48219 ',
#   'number': 16150,
#   'street': 'LENORE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.280333,
#   'latitude': 42.407989,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544300,
#   'blkgrpce': 1},
#  {'address_full': '17490 GODDARD DETROIT, MI 48212 ',
#   'number': 17490,
#   'street': 'GODDARD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.078011,
#   'latitude': 42.422263,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507200,
#   'blkgrpce': 1},
#  {'address_full': '15122 DACOSTA DETROIT, MI 48223 ',
#   'number': 15122,
#   'street': 'DACOSTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.260136,
#   'latitude': 42.399337,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544800,
#   'blkgrpce': 2},
#  {'address_full': '3704 E FERRY DETROIT, MI 48211 ',
#   'number': 3704,
#   'street': 'E FERRY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48211',
#   'longitude': -83.030998,
#   'latitude': 42.374202,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 519100,
#   'blkgrpce': 1},
#  {'address_full': '20501 LINDSAY DETROIT, MI 48235 ',
#   'number': 20501,
#   'street': 'LINDSAY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.215248,
#   'latitude': 42.442822,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540100,
#   'blkgrpce': 3},
#  {'address_full': '725 WHITMORE RD DETROIT, MI 48203 ',
#   'number': 725,
#   'street': 'WHITMORE RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.112419,
#   'latitude': 42.419219,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538300,
#   'blkgrpce': 1},
#  {'address_full': '15338 PRAIRIE DETROIT, MI 48238 ',
#   'number': 15338,
#   'street': 'PRAIRIE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.144526,
#   'latitude': 42.403249,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536300,
#   'blkgrpce': 2},
#  {'address_full': '7329 DOLPHIN DETROIT, MI 48239 ',
#   'number': 7329,
#   'street': 'DOLPHIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48239',
#   'longitude': -83.256582,
#   'latitude': 42.343711,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546201,
#   'blkgrpce': 1},
#  {'address_full': '17172 PRAIRIE DETROIT, MI 48221 ',
#   'number': 17172,
#   'street': 'PRAIRIE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.144937,
#   'latitude': 42.418212,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538500,
#   'blkgrpce': 3},
#  {'address_full': '12211 APPOLINE DETROIT, MI 48227 ',
#   'number': 12211,
#   'street': 'APPOLINE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.169843,
#   'latitude': 42.377729,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535200,
#   'blkgrpce': 1},
#  {'address_full': '15335 FERGUSON DETROIT, MI 48227 ',
#   'number': 15335,
#   'street': 'FERGUSON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.209706,
#   'latitude': 42.402116,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542200,
#   'blkgrpce': 2},
#  {'address_full': '14225 BENTLER DETROIT, MI 48223 ',
#   'number': 14225,
#   'street': 'BENTLER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.251866,
#   'latitude': 42.390176,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544800,
#   'blkgrpce': 1},
#  {'address_full': '3323 KENDALL DETROIT, MI 48238 ',
#   'number': 3323,
#   'street': 'KENDALL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.132681,
#   'latitude': 42.394801,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531600,
#   'blkgrpce': 2},
#  {'address_full': '4876 MARLBOROUGH DETROIT, MI 48224 ',
#   'number': 4876,
#   'street': 'MARLBOROUGH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.957219,
#   'latitude': 42.395305,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502700,
#   'blkgrpce': 1},
#  {'address_full': '1020 ALTER DETROIT, MI ',
#   'number': 1020,
#   'street': 'ALTER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': 'nan',
#   'longitude': -82.939488,
#   'latitude': 42.375412,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 1},
#  {'address_full': '9201 WEST PARKWAY DETROIT, MI 48239 ',
#   'number': 9201,
#   'street': 'WEST PARKWAY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48239',
#   'longitude': -83.265765,
#   'latitude': 42.361977,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546301,
#   'blkgrpce': 1},
#  {'address_full': '20460 PICADILLY DETROIT, MI 48221 ',
#   'number': 20460,
#   'street': 'PICADILLY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.137362,
#   'latitude': 42.444709,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538100,
#   'blkgrpce': 1},
#  {'address_full': '13343 LORETTO DETROIT, MI 48205 ',
#   'number': 13343,
#   'street': 'LORETTO',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.979674,
#   'latitude': 42.41955,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 504000,
#   'blkgrpce': 1},
#  {'address_full': '5703 LONYO DETROIT, MI 48210 ',
#   'number': 5703,
#   'street': 'LONYO',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.147371,
#   'latitude': 42.334037,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 526100,
#   'blkgrpce': 1},
#  {'address_full': '6404 BRUSH DETROIT, MI 48202 ',
#   'number': 6404,
#   'street': 'BRUSH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.067201,
#   'latitude': 42.37038,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511900,
#   'blkgrpce': 1},
#  {'address_full': '8203 PREST DETROIT, MI 48228 ',
#   'number': 8203,
#   'street': 'PREST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.195925,
#   'latitude': 42.353558,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535800,
#   'blkgrpce': 3},
#  {'address_full': '4915 CABOT DETROIT, MI 48210 ',
#   'number': 4915,
#   'street': 'CABOT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.148769,
#   'latitude': 42.328145,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 526000,
#   'blkgrpce': 1},
#  {'address_full': '13210 TIREMAN DETROIT, MI 48228 ',
#   'number': 13210,
#   'street': 'TIREMAN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.174223,
#   'latitude': 42.351592,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535600,
#   'blkgrpce': 3},
#  {'address_full': '7771 WYKES DETROIT, MI 48204 ',
#   'number': 7771,
#   'street': 'WYKES',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.1423,
#   'latitude': 42.350626,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 526500,
#   'blkgrpce': 1},
#  {'address_full': '6420 SOUTH DETROIT, MI 48209 ',
#   'number': 6420,
#   'street': 'SOUTH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48209',
#   'longitude': -83.102514,
#   'latitude': 42.301337,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 524600,
#   'blkgrpce': 1},
#  {'address_full': '4836 SPRINGLE DETROIT, MI 48215 ',
#   'number': 4836,
#   'street': 'SPRINGLE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.968143,
#   'latitude': 42.390789,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502700,
#   'blkgrpce': 4},
#  {'address_full': '164 E SAVANNAH DETROIT, MI 48203 ',
#   'number': 164,
#   'street': 'E SAVANNAH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.098917,
#   'latitude': 42.425294,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509000,
#   'blkgrpce': 4},
#  {'address_full': '8939 MENDOTA DETROIT, MI 48204 ',
#   'number': 8939,
#   'street': 'MENDOTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.164486,
#   'latitude': 42.360806,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535700,
#   'blkgrpce': 1},
#  {'address_full': '3246 GLYNN CT DETROIT, MI 48206 ',
#   'number': 3246,
#   'street': 'GLYNN CT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.118886,
#   'latitude': 42.37667,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531100,
#   'blkgrpce': 1},
#  {'address_full': '5427 CECIL DETROIT, MI 48210 ',
#   'number': 5427,
#   'street': 'CECIL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.135897,
#   'latitude': 42.335988,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 526300,
#   'blkgrpce': 1},
#  {'address_full': '22597 LEEWIN DETROIT, MI 48219 ',
#   'number': 22597,
#   'street': 'LEEWIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.26703,
#   'latitude': 42.43682,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541500,
#   'blkgrpce': 2},
#  {'address_full': '4007 MCKINLEY DETROIT, MI 48208 ',
#   'number': 4007,
#   'street': 'MCKINLEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48208',
#   'longitude': -83.100093,
#   'latitude': 42.338083,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 522800,
#   'blkgrpce': 2},
#  {'address_full': '18393 GRAYFIELD DETROIT, MI 48219 ',
#   'number': 18393,
#   'street': 'GRAYFIELD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.270052,
#   'latitude': 42.42441,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541400,
#   'blkgrpce': 3},
#  {'address_full': '19539 ALCOY DETROIT, MI 48205 ',
#   'number': 19539,
#   'street': 'ALCOY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.989258,
#   'latitude': 42.439066,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503300,
#   'blkgrpce': 2},
#  {'address_full': '10356 BRITAIN DETROIT, MI 48224 ',
#   'number': 10356,
#   'street': 'BRITAIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.941598,
#   'latitude': 42.420057,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500900,
#   'blkgrpce': 2},
#  {'address_full': '4808 DUBOIS DETROIT, MI 48211 ',
#   'number': 4808,
#   'street': 'DUBOIS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48211',
#   'longitude': -83.041989,
#   'latitude': 42.364185,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 519000,
#   'blkgrpce': 2},
#  {'address_full': '20944 LYNDON DETROIT, MI 48223 ',
#   'number': 20944,
#   'street': 'LYNDON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.247753,
#   'latitude': 42.393475,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544800,
#   'blkgrpce': 2},
#  {'address_full': '1143 ASHLAND DETROIT, MI 48215 ',
#   'number': 1143,
#   'street': 'ASHLAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.941931,
#   'latitude': 42.376336,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 1},
#  {'address_full': '13191 MORAN DETROIT, MI 48212 ',
#   'number': 13191,
#   'street': 'MORAN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.061983,
#   'latitude': 42.414056,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509100,
#   'blkgrpce': 3},
#  {'address_full': '9443 CAMLEY DETROIT, MI 48224 ',
#   'number': 9443,
#   'street': 'CAMLEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.932818,
#   'latitude': 42.422177,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500800,
#   'blkgrpce': 2},
#  {'address_full': '15838 INDIANA DETROIT, MI 48221 ',
#   'number': 15838,
#   'street': 'INDIANA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.157461,
#   'latitude': 42.408513,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536300,
#   'blkgrpce': 1},
#  {'address_full': '13246 ROBSON DETROIT, MI 48227 ',
#   'number': 13246,
#   'street': 'ROBSON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.192086,
#   'latitude': 42.384669,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537300,
#   'blkgrpce': 3},
#  {'address_full': '11525 BEACONSFIELD DETROIT, MI 48224 ',
#   'number': 11525,
#   'street': 'BEACONSFIELD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.94478,
#   'latitude': 42.426119,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500700,
#   'blkgrpce': 2},
#  {'address_full': '12154 MONTROSE DETROIT, MI 48227 ',
#   'number': 12154,
#   'street': 'MONTROSE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.199768,
#   'latitude': 42.376912,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 545100,
#   'blkgrpce': 2},
#  {'address_full': '19988 PRAIRIE DETROIT, MI 48221 ',
#   'number': 19988,
#   'street': 'PRAIRIE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.145789,
#   'latitude': 42.440082,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539000,
#   'blkgrpce': 2},
#  {'address_full': '20121 TRINITY DETROIT, MI 48219 ',
#   'number': 20121,
#   'street': 'TRINITY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.25054,
#   'latitude': 42.439908,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540900,
#   'blkgrpce': 2},
#  {'address_full': '9582 PREST DETROIT, MI 48227 ',
#   'number': 9582,
#   'street': 'PREST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.195892,
#   'latitude': 42.366651,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 3},
#  {'address_full': '19206 CHARLESTON DETROIT, MI 48203 ',
#   'number': 19206,
#   'street': 'CHARLESTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.107014,
#   'latitude': 42.433788,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 508000,
#   'blkgrpce': 1},
#  {'address_full': '14129 RUTLAND DETROIT, MI 48227 ',
#   'number': 14129,
#   'street': 'RUTLAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.213755,
#   'latitude': 42.389614,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542500,
#   'blkgrpce': 1},
#  {'address_full': '612 MARSTON DETROIT, MI 48202 ',
#   'number': 612,
#   'street': 'MARSTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.06838,
#   'latitude': 42.377582,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511200,
#   'blkgrpce': 1},
#  {'address_full': '18518 PELKEY DETROIT, MI 48205 ',
#   'number': 18518,
#   'street': 'PELKEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.985848,
#   'latitude': 42.431149,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503500,
#   'blkgrpce': 2},
#  {'address_full': '8284 INDIANA DETROIT, MI 48204 ',
#   'number': 8284,
#   'street': 'INDIANA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.155084,
#   'latitude': 42.355446,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534700,
#   'blkgrpce': 1},
#  {'address_full': '18304 STRATHMOOR DETROIT, MI 48235 ',
#   'number': 18304,
#   'street': 'STRATHMOOR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.188317,
#   'latitude': 42.425101,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539600,
#   'blkgrpce': 1},
#  {'address_full': '2156 PHILIP DETROIT, MI 48215 ',
#   'number': 2156,
#   'street': 'PHILIP',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.946187,
#   'latitude': 42.380327,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 1},
#  {'address_full': '18631 CHERRYLAWN DETROIT, MI 48221 ',
#   'number': 18631,
#   'street': 'CHERRYLAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.155738,
#   'latitude': 42.428339,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538600,
#   'blkgrpce': 3},
#  {'address_full': '19955 WALTHAM DETROIT, MI 48205 ',
#   'number': 19955,
#   'street': 'WALTHAM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.995581,
#   'latitude': 42.443246,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503200,
#   'blkgrpce': 2},
#  {'address_full': '550 SMITH DETROIT, MI 48202 ',
#   'number': 550,
#   'street': 'SMITH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.068369,
#   'latitude': 42.375514,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511200,
#   'blkgrpce': 1},
#  {'address_full': '18490 LAUDER DETROIT, MI 48235 ',
#   'number': 18490,
#   'street': 'LAUDER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.192124,
#   'latitude': 42.426576,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539600,
#   'blkgrpce': 2},
#  {'address_full': '18032 FENMORE DETROIT, MI 48235 ',
#   'number': 18032,
#   'street': 'FENMORE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.217629,
#   'latitude': 42.421528,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540400,
#   'blkgrpce': 2},
#  {'address_full': '3409 MONTCLAIR DETROIT, MI 48214 ',
#   'number': 3409,
#   'street': 'MONTCLAIR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -82.982844,
#   'latitude': 42.374236,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 513900,
#   'blkgrpce': 2},
#  {'address_full': '11990 RADOM DETROIT, MI 48212 ',
#   'number': 11990,
#   'street': 'RADOM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.049898,
#   'latitude': 42.409222,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 510600,
#   'blkgrpce': 3},
#  {'address_full': '14311 CHANDLER PARK DR DETROIT, MI 48213 ',
#   'number': 14311,
#   'street': 'CHANDLER PARK DR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.963063,
#   'latitude': 42.40048,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502600,
#   'blkgrpce': 3},
#  {'address_full': '11067 WAYBURN DETROIT, MI 48224 ',
#   'number': 11067,
#   'street': 'WAYBURN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.955557,
#   'latitude': 42.419145,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501000,
#   'blkgrpce': 2},
#  {'address_full': '16162 STRATHMOOR DETROIT, MI 48235 ',
#   'number': 16162,
#   'street': 'STRATHMOOR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.187846,
#   'latitude': 42.410088,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537600,
#   'blkgrpce': 2},
#  {'address_full': '3145 CHARLEVOIX DETROIT, MI 48207 ',
#   'number': 3145,
#   'street': 'CHARLEVOIX',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48207',
#   'longitude': -83.026192,
#   'latitude': 42.354579,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 516800,
#   'blkgrpce': 1},
#  {'address_full': '2305 BLAINE DETROIT, MI 48206 ',
#   'number': 2305,
#   'street': 'BLAINE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.10237,
#   'latitude': 42.370948,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533100,
#   'blkgrpce': 2},
#  {'address_full': '4187 COPLIN DETROIT, MI 48215 ',
#   'number': 4187,
#   'street': 'COPLIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.960567,
#   'latitude': 42.387589,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502700,
#   'blkgrpce': 3},
#  {'address_full': '15810 HARTWELL DETROIT, MI 48235 ',
#   'number': 15810,
#   'street': 'HARTWELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.177977,
#   'latitude': 42.407778,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537000,
#   'blkgrpce': 1},
#  {'address_full': '2937 BUENA VISTA DETROIT, MI 48238 ',
#   'number': 2937,
#   'street': 'BUENA VISTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.124106,
#   'latitude': 42.389424,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531502,
#   'blkgrpce': 1}]

# %%
## creating the rabbit_cleaners_price function, which calls the taskrabbit API and retrieves the median price for a "medium" cleaning job at the designated address

import requests
import json

def rabbit_cleaners_price(places):
    
    headers = {
        'accept': '*/*',
        'accept-language': 'en-US,en;q=0.9',
        'content-type': 'application/json',
        # 'cookie': 'uid=2d7ea5a9-5bff-4bf1-a8d9-59ac8d7e84ab; last_locale=en-US; ajs_anonymous_id=7ffd6673-20c1-44ad-8133-5d2c2dc62240; _gcl_au=1.1.1950151795.1721399863; _tt_enable_cookie=1; _ttp=OivcnuJe6Z5F601mWb67riugEkQ; _fbp=fb.1.1721399863787.614230970990065288; _gid=GA1.2.1569097439.1721399864; __pdst=9d0b0e73d8d342979266543cd6e9b99a; sa-user-id=s%253A0-ee8b8dec-1e49-5763-7e02-10d82e69497a.aseT4%252F4X%252FyOqGwngDChgGfO2i6%252FqzStF96W%252F9cxFArg; sa-user-id-v2=s%253A7ouN7B5JV2N-AhDYLmlJekV11dY.rzCClHQGAxsw2rcutID3RYGv0OqJZVbV6AlAmQDS8C0; sa-user-id-v3=s%253AAQAKIB_ZZxwFCe3MrCWhgdnFtF1pPWo7liNQrezWGnw3xeFeEAEYAyCU9sqnBjABOgRrkJNFQgRvYG_w.ANmSM2rkyHMKtCfOZIVvAtuzLbUubYKzrnR3bGnerHY; ndp_session_id=ca22b3d1-17dc-4224-b321-3f3043c26ad0; _clck=xjswly%7C2%7Cfnl%7C0%7C1661; __ssid=6104a5b4038a38c30bf9ecab48520b0; event_metadata=%7B%22segment_session_id%22%3A%2222ea08ff-2f21-46b6-90b6-de63adf89468%22%2C%22utm%22%3Anull%7D; optimizelyEndUserId=oeu1721402153899r0.549056180666248; sa-r-source=www.google.com; __stripe_mid=7abb74fa-baab-421f-8b20-ff6bdf3ea6f9198f0e; __stripe_sid=80ccb9c2-d93b-4e1c-a0a4-612b0805e190bb6206; client_width=1192; session=1721402260; ajs_user_id=23005034; ab=87%3A%3A1721407772%3A%3A%3AIncreaseReferralCtaC%3ASidebarNavigation%3AChat2Oh%3ASearchDropDownMenuV%3APersonalizationEmailC%3A; sa-r-date=2024-07-19T15:49:33.413Z; XSRF-TOKEN=5oxtcV0WHX3NDMQkQxgfsvqPwmvsE9C1Qs1h6Uo33a__ZN5Mr8Dwal46y9Q3zYGsSI0q9SN3F3T_D8juHD5QpA; navigation_depth=18; _ga_VY692PC94C=GS1.1.1721402154.2.1.1721404178.55.0.0; _ga=GA1.2.1135124843.1721399864; _rdt_uuid=1721399864193.74fdd548-922a-4aaf-98f8-d9549d785314; _uetsid=7586aa8045dc11efb1fe85eb97d1f5b0; _uetvid=7586a6f045dc11efb2fd03957600c19b; _clsk=1i1m546%7C1721404179625%7C17%7C1%7Cn.clarity.ms%2Fcollect; _dd_s=rum=0&expire=1721405190348; tr6=l3wF2SLj25IBeeeo%2FMe4kWfNScR%2F1U73xOHdfp%2B1agO%2B5385EPeXElpg2HlrO4Z409e3pN6j%2BdzYek9MRFhQYJZ2g9pqpGuDKjVTxdErbQA9MXIy9%2FL88PPHQpRzXJWQFPEVZkQlvSezCPMddPlzr7e%2F97WNsStkP53EhfPYKG8ikkODKKJvQqKJQnQDCZUffoFDLZ8jMWj27Z7DSQl0UBVhu5If9eyTlHSZRAWoevkTvUCsHEu6dK2l%2FC6gtc3bIUz9DZ%2BiW%2Fe4AMbDrZ9J75fwA3F%2FDcc%2BVlYHLEmAG3IGps%2BJc3RhEY0MQr042a9cdohAI24YdBcRovPOiLMT3bICU0PwxN00Kx7G6%2BjajRGNXhRdYn0YvWIKP%2BY2YGvqqOAwUrie9rXT4FXogb6cDvZNEqbpkH%2B54NNZfZnADwOXk17m48Yx8jhKtSL6O7uO4Hy8S3g%2B%2BeGfDBYuHzsYnNkOnxjsa%2BoBc48J%2FMbEOIarootsuha30GsCVu5bbXYQGge%2F4stvV4qH3SYIpzFk15bxY0IPizJcpbZ86pcBhgNlUAWQ6etrorWl3B2GkeAi8iwyH9vwQD0pPRD1kPF1BfnzW3TX66tUw%2FNnvxurmkJirlCSteplu5xgXJfj7ESTa0qrXTxe9xwn8VA%2F67z8tQgRr3eE1broIDfQAwYFx4j3A2ediT%2FcuOV9vBrI6wQl%2BBVRdRnhNMl0Eq1R1wNbNWnTWP8GSZEJYs9acmvuqotC--8efwI4ujy%2FnJT8hN--XgPWeaywLOXsENZR7oeS3g%3D%3D',
        'priority': 'u=1, i',
        'referer': 'https://www.taskrabbit.com/book/2270/details?category_id=59&form_referrer=dashboard__initial_tags&funnel_id=2d7ea5a9-5bff-4bf1-a8d9-59ac8d7e84ab_1721404177642&job_draft_guid=17f821b4-c572-4974-b385-42cf4ebe9927&uuid=da2a92a5-f2a7-4c42-8fda-a4e2eb18f369',
        'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    }
    
    inputs = {
        "0":{"json":{"bootstrap":True,"categoryId":59,"funnelId":"2d7ea5a9-5bff-4bf1-a8d9-59ac8d7e84ab_1721404177642","isRecosPage":True,"lat":lat,"lng":lng,"locale":"en-US","location":{"country":"United States","formattedAddress":address,"postalCode":zip_code},"schedule":{"dates":[{"date":"2024-07-19","duration_seconds":86400,"offset_seconds":0},{"date":"2024-07-20","duration_seconds":86400,"offset_seconds":0},{"date":"2024-07-21","duration_seconds":86400,"offset_seconds":0},{"date":"2024-07-22","duration_seconds":86400,"offset_seconds":0},{"date":"2024-07-23","duration_seconds":86400,"offset_seconds":0},{"date":"2024-07-24","duration_seconds":86400,"offset_seconds":0},{"date":"2024-07-25","duration_seconds":86400,"offset_seconds":0}],"dayTimeRanges":[]},"vehicleRequirement":None},"meta":{"values":{"vehicleRequirement":["undefined"]}}}
    }
    
    params = {
        'batch': '1',
        'input': json.dumps(inputs),
    }
    
    response = requests.get(
        'https://www.taskrabbit.com/next-api/trpc/page.book.recommendations',
        params=params,
        headers=headers,
    )
    
    return response.json()[0]['result']['data']['json']['bff']['histogram']['formatted_median_price']

# %%
## looping through the addresses, retrieving the median hourly price for a taskrabbit cleaner, and appending that price to the address's dictionary

for place in address_list:
    address = place['address_full']
    lat = place['latitude']
    lng = place['longitude']
    zip_code = place['zip']
    place['median_cleaning_price'] = rabbit_cleaners_price(place)
    ##print(f"{address}   median price: {rabbit_cleaners_price(place)}")

# %%
## retrieving the median household income for each addresses' census block group from the American Community Survey API and apending it to the list of addresses

for place in address_list:
    block = place['blkgrpce']
    state = place['statefp']
    county = place['countyfp']
    tract = place['tractce']
    url = f"https://api.census.gov/data/2023/pdb/blockgroup?get=Med_HHD_Inc_BG_ACS_17_21&for=block%20group:{block}&in=state:{state}%20county:{county}%20tract:{tract}"
    response = requests.get(url)
    ACS = response.json()
    place['median_household_income_17-21'] = ACS[1][0]

# %%
## converting the list of address dictionaries back into a dataframe, including the median hourly cleaning price and median household income

cleaning_prices = pd.DataFrame(address_list)
cleaning_prices
# Out:
#                             address_full  number       street     city state  \
# 0         748 DUNKIRK DETROIT, MI 48217      748      DUNKIRK  DETROIT    MI
# 1        1558 CALVERT DETROIT, MI 48206     1558      CALVERT  DETROIT    MI
# 2        8083 NORMILE DETROIT, MI 48204     8083      NORMILE  DETROIT    MI
# 3        4054 RICHTON DETROIT, MI 48204     4054      RICHTON  DETROIT    MI
# 4         8317 PENROD DETROIT, MI 48228     8317       PENROD  DETROIT    MI
# ..                                   ...     ...          ...      ...   ...
# 195   3145 CHARLEVOIX DETROIT, MI 48207     3145   CHARLEVOIX  DETROIT    MI
# 196       2305 BLAINE DETROIT, MI 48206     2305       BLAINE  DETROIT    MI
# 197       4187 COPLIN DETROIT, MI 48215     4187       COPLIN  DETROIT    MI
# 198    15810 HARTWELL DETROIT, MI 48235    15810     HARTWELL  DETROIT    MI
# 199  2937 BUENA VISTA DETROIT, MI 48238     2937  BUENA VISTA  DETROIT    MI
#
#        zip  longitude   latitude  statefp  countyfp  tractce  blkgrpce  \
# 0    48217 -83.150601  42.286192       26       163   524500         2
# 1    48206 -83.100993  42.384252       26       163   531900         1
# 2    48204 -83.158999  42.352950       26       163   535600         4
# 3    48204 -83.130003  42.381745       26       163   530900         2
# 4    48228 -83.220193  42.354021       26       163   546000         2
# ..     ...        ...        ...      ...       ...      ...       ...
# 195  48207 -83.026192  42.354579       26       163   516800         1
# 196  48206 -83.102370  42.370948       26       163   533100         2
# 197  48215 -82.960567  42.387589       26       163   502700         3
# 198  48235 -83.177977  42.407778       26       163   537000         1
# 199  48238 -83.124106  42.389424       26       163   531502         1
#
#     median_cleaning_price median_household_income_17-21
# 0                  $27.87                         18750
# 1                  $30.97                         27197
# 2                  $27.87                         36571
# 3                  $30.97                         53333
# 4                  $27.87                         23315
# ..                    ...                           ...
# 195                $29.42                         29500
# 196                $30.97                         24479
# 197                $35.61                          None
# 198                $30.45                         54375
# 199                $30.97                          None
#
# [200 rows x 14 columns]

# %%
## converting the median household income and median cleaning value to floats

import numpy as np

cleaning_prices['median_household_income_17-21'] = (
    cleaning_prices['median_household_income_17-21']
    .replace("None", np.nan)
    .astype(float)
)

cleaning_prices['median_cleaning_price'] = (
    cleaning_prices['median_cleaning_price']
    .str.replace("$", "")
    .astype(float)
)

# %%
## saving the new dataframe to a csv because the api call loops take forever to process

cleaning_prices.to_csv("detroit_cleaning_prices.csv")

# %%
cleaning_prices
# Out:
#                             address_full  number       street     city state  \
# 0         748 DUNKIRK DETROIT, MI 48217      748      DUNKIRK  DETROIT    MI
# 1        1558 CALVERT DETROIT, MI 48206     1558      CALVERT  DETROIT    MI
# 2        8083 NORMILE DETROIT, MI 48204     8083      NORMILE  DETROIT    MI
# 3        4054 RICHTON DETROIT, MI 48204     4054      RICHTON  DETROIT    MI
# 4         8317 PENROD DETROIT, MI 48228     8317       PENROD  DETROIT    MI
# ..                                   ...     ...          ...      ...   ...
# 195   3145 CHARLEVOIX DETROIT, MI 48207     3145   CHARLEVOIX  DETROIT    MI
# 196       2305 BLAINE DETROIT, MI 48206     2305       BLAINE  DETROIT    MI
# 197       4187 COPLIN DETROIT, MI 48215     4187       COPLIN  DETROIT    MI
# 198    15810 HARTWELL DETROIT, MI 48235    15810     HARTWELL  DETROIT    MI
# 199  2937 BUENA VISTA DETROIT, MI 48238     2937  BUENA VISTA  DETROIT    MI
#
#        zip  longitude   latitude  statefp  countyfp  tractce  blkgrpce  \
# 0    48217 -83.150601  42.286192       26       163   524500         2
# 1    48206 -83.100993  42.384252       26       163   531900         1
# 2    48204 -83.158999  42.352950       26       163   535600         4
# 3    48204 -83.130003  42.381745       26       163   530900         2
# 4    48228 -83.220193  42.354021       26       163   546000         2
# ..     ...        ...        ...      ...       ...      ...       ...
# 195  48207 -83.026192  42.354579       26       163   516800         1
# 196  48206 -83.102370  42.370948       26       163   533100         2
# 197  48215 -82.960567  42.387589       26       163   502700         3
# 198  48235 -83.177977  42.407778       26       163   537000         1
# 199  48238 -83.124106  42.389424       26       163   531502         1
#
#      median_cleaning_price  median_household_income_17-21
# 0                    27.87                        18750.0
# 1                    30.97                        27197.0
# 2                    27.87                        36571.0
# 3                    30.97                        53333.0
# 4                    27.87                        23315.0
# ..                     ...                            ...
# 195                  29.42                        29500.0
# 196                  30.97                        24479.0
# 197                  35.61                            NaN
# 198                  30.45                        54375.0
# 199                  30.97                            NaN
#
# [200 rows x 14 columns]
