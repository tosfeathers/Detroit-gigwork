# %%
import requests
import pandas as pd
import json
import numpy as np
import statistics
from tqdm import tqdm
import time
import re

# %%
## reading in the csv of Detroit addresses (with median taskrabbit cleaning rates and median household income included)

gigwork = pd.read_csv("senior_pet_special_line_cleaning_detroit.csv")

gigwork['zip'] = (
    gigwork['zip']
    .astype(str)
    .str.replace(".0", "")
)

gigwork.head()
# Out:
#                       address_full  number   street     city state    zip  \
# 0   748 DUNKIRK DETROIT, MI 48217      748  DUNKIRK  DETROIT    MI  48217
# 1  1558 CALVERT DETROIT, MI 48206     1558  CALVERT  DETROIT    MI  48206
# 2  8083 NORMILE DETROIT, MI 48204     8083  NORMILE  DETROIT    MI  48204
# 3  4054 RICHTON DETROIT, MI 48204     4054  RICHTON  DETROIT    MI  48204
# 4   8317 PENROD DETROIT, MI 48228     8317   PENROD  DETROIT    MI  48228
#
#    longitude   latitude  statefp  countyfp  ...  blkgrpce  \
# 0 -83.150601  42.286192       26       163  ...         2
# 1 -83.100993  42.384252       26       163  ...         1
# 2 -83.158999  42.352950       26       163  ...         4
# 3 -83.130003  42.381745       26       163  ...         2
# 4 -83.220193  42.354021       26       163  ...         2
#
#    median_cleaning_price  median_household_income_17-21  \
# 0                  27.87                        18750.0
# 1                  30.97                        27197.0
# 2                  27.87                        36571.0
# 3                  30.97                        53333.0
# 4                  27.87                        23315.0
#
#    seniorcare_median_price  median_line_price  petcare_median_price  \
# 0                     20.5              25.80                  17.5
# 1                     23.0              28.38                  17.5
# 2                     22.0              30.97                  17.5
# 3                     22.0              28.90                  17.5
# 4                     22.5              28.90                  17.5
#
#    spclneeds_median_price  single_child_living_wage  \
# 0                   20.00                     37.22
# 1                   20.00                     37.22
# 2                   20.00                     37.22
# 3                   20.00                     37.22
# 4                   19.25                     37.22
#
#    single_nochild_living_wage  couple_child_living_wage
# 0                       20.42                     20.89
# 1                       20.42                     20.89
# 2                       20.42                     20.89
# 3                       20.42                     20.89
# 4                       20.42                     20.89
#
# [5 rows x 21 columns]

# %%
## converting the address dataframe to a list

gigwork_list = gigwork.to_dict('records')
gigwork_list
# Out:
# [{'address_full': '748 DUNKIRK DETROIT, MI 48217 ',
#   'number': 748,
#   'street': 'DUNKIRK',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48217',
#   'longitude': -83.150601,
#   'latitude': 42.286192,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 524500,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 18750.0,
#   'seniorcare_median_price': 20.5,
#   'median_line_price': 25.8,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '1558 CALVERT DETROIT, MI 48206 ',
#   'number': 1558,
#   'street': 'CALVERT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.100993,
#   'latitude': 42.384252,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531900,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 27197.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8083 NORMILE DETROIT, MI 48204 ',
#   'number': 8083,
#   'street': 'NORMILE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.158999,
#   'latitude': 42.35295,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535600,
#   'blkgrpce': 4,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 36571.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '4054 RICHTON DETROIT, MI 48204 ',
#   'number': 4054,
#   'street': 'RICHTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.130003,
#   'latitude': 42.381745,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 530900,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 53333.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8317 PENROD DETROIT, MI 48228 ',
#   'number': 8317,
#   'street': 'PENROD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.220193,
#   'latitude': 42.354021,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 23315.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '5286 ALLENDALE DETROIT, MI ',
#   'number': 5286,
#   'street': 'ALLENDALE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.124704,
#   'latitude': 42.354423,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533600,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 27857.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18422 KELLY RD DETROIT, MI 48224 ',
#   'number': 18422,
#   'street': 'KELLY RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.956106,
#   'latitude': 42.429932,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500700,
#   'blkgrpce': 4,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 47466.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 29.42,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '6238 LINWOOD DETROIT, MI 48208 ',
#   'number': 6238,
#   'street': 'LINWOOD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48208',
#   'longitude': -83.098017,
#   'latitude': 42.358668,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 522300,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 11463.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '14358 MONTROSE DETROIT, MI 48227 ',
#   'number': 14358,
#   'street': 'MONTROSE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.20016,
#   'latitude': 42.392622,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542400,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 19100.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '21671 GREYDALE CT DETROIT, MI 48219 ',
#   'number': 21671,
#   'street': 'GREYDALE CT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.257121,
#   'latitude': 42.43001,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541000,
#   'blkgrpce': 3,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 53189.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '17177 FENTON DETROIT, MI 48219 ',
#   'number': 17177,
#   'street': 'FENTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.282615,
#   'latitude': 42.415507,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 53125.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '11404 BRAMELL DETROIT, MI 48239 ',
#   'number': 11404,
#   'street': 'BRAMELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48239',
#   'longitude': -83.262891,
#   'latitude': 42.370694,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546301,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 50250.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '875 MARLBOROUGH DETROIT, MI 48215 ',
#   'number': 875,
#   'street': 'MARLBOROUGH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.943046,
#   'latitude': 42.37226,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 513200,
#   'blkgrpce': 2,
#   'median_cleaning_price': 33.03,
#   'median_household_income_17-21': 29107.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 28.39,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '7217 ST PAUL DETROIT, MI 48214 ',
#   'number': 7217,
#   'street': 'ST PAUL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -83.005856,
#   'latitude': 42.354167,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 515300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 45972.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '460 W CANFIELD 31 DETROIT, MI 48201 ',
#   'number': 460,
#   'street': 'W CANFIELD 31',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48201',
#   'longitude': -83.065538,
#   'latitude': 42.351921,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 520300,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 78791.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '5896 ST CLAIR DETROIT, MI 48213 ',
#   'number': 5896,
#   'street': 'ST CLAIR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.998512,
#   'latitude': 42.39315,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505700,
#   'blkgrpce': 5,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 35186.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 29.42,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '425 W SAVANNAH DETROIT, MI 48203 ',
#   'number': 425,
#   'street': 'W SAVANNAH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.107587,
#   'latitude': 42.425101,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509000,
#   'blkgrpce': 3,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 27941.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '1228 NEWPORT DETROIT, MI 48215 ',
#   'number': 1228,
#   'street': 'NEWPORT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.947943,
#   'latitude': 42.375144,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 1,
#   'median_cleaning_price': 33.03,
#   'median_household_income_17-21': 24886.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 28.39,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '10231 MENDOTA DETROIT, MI 48204 ',
#   'number': 10231,
#   'street': 'MENDOTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.164779,
#   'latitude': 42.370127,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534400,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 19245.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '4616 CHALMERS DETROIT, MI 48215 ',
#   'number': 4616,
#   'street': 'CHALMERS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.956573,
#   'latitude': 42.392534,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502700,
#   'blkgrpce': 1,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 23333.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20153 RUSSELL DETROIT, MI 48203 ',
#   'number': 20153,
#   'street': 'RUSSELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.091332,
#   'latitude': 42.443146,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507500,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 16711.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.87,
#   'petcare_median_price': 17.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15778 WISCONSIN DETROIT, MI 48238 ',
#   'number': 15778,
#   'street': 'WISCONSIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.156374,
#   'latitude': 42.407437,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 30738.0,
#   'seniorcare_median_price': 23.25,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '16249 HUBBELL DETROIT, MI 48235 ',
#   'number': 16249,
#   'street': 'HUBBELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.189658,
#   'latitude': 42.411218,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537600,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 27917.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19185 BELAND DETROIT, MI 48234 ',
#   'number': 19185,
#   'street': 'BELAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.009329,
#   'latitude': 42.435616,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505600,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 30833.0,
#   'seniorcare_median_price': 22.75,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 21.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20310 W GRAND RIVER DETROIT, MI 48219 ',
#   'number': 20310,
#   'street': 'W GRAND RIVER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.240979,
#   'latitude': 42.410118,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543200,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 57292.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19921 WARRINGTON DETROIT, MI 48221 ',
#   'number': 19921,
#   'street': 'WARRINGTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.140979,
#   'latitude': 42.439329,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538100,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 73972.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.35,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19520 W GRAND RIVER DETROIT, MI 48223 ',
#   'number': 19520,
#   'street': 'W GRAND RIVER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.234145,
#   'latitude': 42.407394,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 60990.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 27.87,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '2257 E KIRBY DETROIT, MI 48211 ',
#   'number': 2257,
#   'street': 'E KIRBY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48211',
#   'longitude': -83.044042,
#   'latitude': 42.368752,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 519100,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19190 WESTBROOK DETROIT, MI 48219 ',
#   'number': 19190,
#   'street': 'WESTBROOK',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.251953,
#   'latitude': 42.430695,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541000,
#   'blkgrpce': 3,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 53189.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '17331 ROSELAWN DETROIT, MI 48221 ',
#   'number': 17331,
#   'street': 'ROSELAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.152791,
#   'latitude': 42.419332,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538500,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 21995.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20103 SANTA ROSA DETROIT, MI 48221 ',
#   'number': 20103,
#   'street': 'SANTA ROSA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.144284,
#   'latitude': 42.441431,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 27004.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 26.84,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '734 25TH ST DETROIT, MI 48216 ',
#   'number': 734,
#   'street': '25TH ST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48216',
#   'longitude': -83.082427,
#   'latitude': 42.316335,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 521100,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 27500.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 26.32,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '5633 TROWBRIDGE HAMTRAMCK, MI 48212 ',
#   'number': 5633,
#   'street': 'TROWBRIDGE',
#   'city': 'HAMTRAMCK',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.045052,
#   'latitude': 42.404563,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 510600,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 16131.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.25,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '1268 DRAGOON DETROIT, MI 48209 ',
#   'number': 1268,
#   'street': 'DRAGOON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48209',
#   'longitude': -83.105187,
#   'latitude': 42.311874,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 523200,
#   'blkgrpce': 3,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '12767 LORETTO DETROIT, MI 48205 ',
#   'number': 12767,
#   'street': 'LORETTO',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.984765,
#   'latitude': 42.417776,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503900,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 30792.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18717 SORRENTO DETROIT, MI 48235 ',
#   'number': 18717,
#   'street': 'SORRENTO',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.174466,
#   'latitude': 42.429256,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539400,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 50938.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.87,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15865 ASHTON DETROIT, MI 48219 ',
#   'number': 15865,
#   'street': 'ASHTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.220116,
#   'latitude': 42.407458,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543000,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 80563.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '14804 MADDELEIN DETROIT, MI 48205 ',
#   'number': 14804,
#   'street': 'MADDELEIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.969575,
#   'latitude': 42.435864,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 39940.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '13646 PIEDMONT DETROIT, MI 48223 ',
#   'number': 13646,
#   'street': 'PIEDMONT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.229411,
#   'latitude': 42.386153,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 543300,
#   'blkgrpce': 4,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '13200 JOY RD DETROIT, MI 48228 ',
#   'number': 13200,
#   'street': 'JOY RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.174111,
#   'latitude': 42.358895,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 53816.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8061 PLAINVIEW DETROIT, MI 48228 ',
#   'number': 8061,
#   'street': 'PLAINVIEW',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.234806,
#   'latitude': 42.351326,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546000,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 37381.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 26.84,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20486 HULL DETROIT, MI 48203 ',
#   'number': 20486,
#   'street': 'HULL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.088924,
#   'latitude': 42.446104,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507500,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 16711.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.35,
#   'petcare_median_price': 17.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '24251 PEMBROKE DETROIT, MI 48219 ',
#   'number': 24251,
#   'street': 'PEMBROKE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.28009,
#   'latitude': 42.435822,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541800,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 35262.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '2477 BEALS DETROIT, MI 48214 ',
#   'number': 2477,
#   'street': 'BEALS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -83.003303,
#   'latitude': 42.361042,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 515200,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 20870.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20203 MOENART DETROIT, MI 48234 ',
#   'number': 20203,
#   'street': 'MOENART',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.050939,
#   'latitude': 42.444422,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 506700,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 48125.0,
#   'seniorcare_median_price': 22.75,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 21.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8371 ROLYAT DETROIT, MI 48234 ',
#   'number': 8371,
#   'street': 'ROLYAT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.018168,
#   'latitude': 42.439878,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505100,
#   'blkgrpce': 3,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 48785.0,
#   'seniorcare_median_price': 22.75,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 21.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '12218 PLAINVIEW DETROIT, MI 48228 ',
#   'number': 12218,
#   'street': 'PLAINVIEW',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.234828,
#   'latitude': 42.376731,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 547100,
#   'blkgrpce': 4,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 51250.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '17822 BRUSH DETROIT, MI 48203 ',
#   'number': 17822,
#   'street': 'BRUSH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.097323,
#   'latitude': 42.423658,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 509000,
#   'blkgrpce': 4,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15237 E STATE FAIR DETROIT, MI 48205 ',
#   'number': 15237,
#   'street': 'E STATE FAIR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.964897,
#   'latitude': 42.442882,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 500200,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 39318.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 27.87,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '11803 GREINER DETROIT, MI 48205 ',
#   'number': 11803,
#   'street': 'GREINER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -83.00291,
#   'latitude': 42.427492,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503500,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 41786.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19954 CHERRYLAWN DETROIT, MI 48221 ',
#   'number': 19954,
#   'street': 'CHERRYLAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.155454,
#   'latitude': 42.439464,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539000,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 40694.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.35,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15428 COYLE DETROIT, MI 48227 ',
#   'number': 15428,
#   'street': 'COYLE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.193595,
#   'latitude': 42.403935,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537500,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 32078.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19136 JOY RD DETROIT, MI 48228 ',
#   'number': 19136,
#   'street': 'JOY RD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.228269,
#   'latitude': 42.357969,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546700,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 41500.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '10452 BONITA DETROIT, MI 48224 ',
#   'number': 10452,
#   'street': 'BONITA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.959671,
#   'latitude': 42.413978,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501100,
#   'blkgrpce': 4,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 31250.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 29.42,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '11214 GLENFIELD DETROIT, MI 48213 ',
#   'number': 11214,
#   'street': 'GLENFIELD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.997289,
#   'latitude': 42.408895,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505200,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 36071.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '3489 ALGONQUIN DETROIT, MI 48215 ',
#   'number': 3489,
#   'street': 'ALGONQUIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.964562,
#   'latitude': 42.382149,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 2,
#   'median_cleaning_price': 36.13,
#   'median_household_income_17-21': 10598.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '9950 LAUDER DETROIT, MI 48227 ',
#   'number': 9950,
#   'street': 'LAUDER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.189462,
#   'latitude': 42.368818,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 37466.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '17337 PREVOST DETROIT, MI 48235 ',
#   'number': 17337,
#   'street': 'PREVOST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.203987,
#   'latitude': 42.418267,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540400,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 52880.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '9911 LAUDER DETROIT, MI 48227 ',
#   'number': 9911,
#   'street': 'LAUDER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.190056,
#   'latitude': 42.368253,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 37466.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18559 ST AUBIN DETROIT, MI 48234 ',
#   'number': 18559,
#   'street': 'ST AUBIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.081775,
#   'latitude': 42.429166,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507100,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 22.75,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 21.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19481 JAMES COUZENS DETROIT, MI 48235 ',
#   'number': 19481,
#   'street': 'JAMES COUZENS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.192127,
#   'latitude': 42.43522,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539700,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 26204.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.35,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18606 BELAND DETROIT, MI 48205 ',
#   'number': 18606,
#   'street': 'BELAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -83.009097,
#   'latitude': 42.430909,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 505600,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 32500.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '22413 LYNDON DETROIT, MI 48223 ',
#   'number': 22413,
#   'street': 'LYNDON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.261864,
#   'latitude': 42.392801,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544100,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 20417.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8092 WISCONSIN DETROIT, MI 48204 ',
#   'number': 8092,
#   'street': 'WISCONSIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.153744,
#   'latitude': 42.353176,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534700,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 30039.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '2587 GRAY DETROIT, MI 48215 ',
#   'number': 2587,
#   'street': 'GRAY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.959383,
#   'latitude': 42.378145,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 2,
#   'median_cleaning_price': 35.61,
#   'median_household_income_17-21': 10598.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '4875 MARSEILLES DETROIT, MI 48224 ',
#   'number': 4875,
#   'street': 'MARSEILLES',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.921098,
#   'latitude': 42.408445,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501700,
#   'blkgrpce': 2,
#   'median_cleaning_price': 33.03,
#   'median_household_income_17-21': 30917.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '4379 LUMLEY DETROIT, MI 48210 ',
#   'number': 4379,
#   'street': 'LUMLEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.13826,
#   'latitude': 42.326746,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 526000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 34027.0,
#   'seniorcare_median_price': 21.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8116 GREENLAWN DETROIT, MI 48204 ',
#   'number': 8116,
#   'street': 'GREENLAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.148428,
#   'latitude': 42.353608,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534800,
#   'blkgrpce': 2,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 33611.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '14156 LAMPHERE DETROIT, MI 48223 ',
#   'number': 14156,
#   'street': 'LAMPHERE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48223',
#   'longitude': -83.26109,
#   'latitude': 42.38909,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 544800,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 32880.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 32.51,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18924 BENTLER DETROIT, MI 48219 ',
#   'number': 18924,
#   'street': 'BENTLER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.253017,
#   'latitude': 42.426822,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 541200,
#   'blkgrpce': 2,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 19042.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15780 SCHAEFER DETROIT, MI 48227 ',
#   'number': 15780,
#   'street': 'SCHAEFER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.178966,
#   'latitude': 42.407102,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537000,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 54375.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '12831 FRANKFORT DETROIT, MI 48213 ',
#   'number': 12831,
#   'street': 'FRANKFORT',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.968113,
#   'latitude': 42.393102,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502600,
#   'blkgrpce': 6,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15348 ILENE DETROIT, MI 48238 ',
#   'number': 15348,
#   'street': 'ILENE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.161557,
#   'latitude': 42.403276,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 536800,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 23.25,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '12039 WHITCOMB DETROIT, MI 48227 ',
#   'number': 12039,
#   'street': 'WHITCOMB',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.195757,
#   'latitude': 42.375389,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 2,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 27422.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19151 DEQUINDRE DETROIT, MI 48234 ',
#   'number': 19151,
#   'street': 'DEQUINDRE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.083209,
#   'latitude': 42.433718,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 507400,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 34875.0,
#   'seniorcare_median_price': 22.75,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 21.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '3426 LIVERNOIS DETROIT, MI 48210 ',
#   'number': 3426,
#   'street': 'LIVERNOIS',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48210',
#   'longitude': -83.116642,
#   'latitude': 42.326646,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 525900,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 27162.0,
#   'seniorcare_median_price': 21.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18251 FITZPATRICK DETROIT, MI 48228 ',
#   'number': 18251,
#   'street': 'FITZPATRICK',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48228',
#   'longitude': -83.218607,
#   'latitude': 42.364604,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 546700,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 43214.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 19.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20183 GODDARD DETROIT, MI 48234 ',
#   'number': 20183,
#   'street': 'GODDARD',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48234',
#   'longitude': -83.078,
#   'latitude': 42.443768,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 506800,
#   'blkgrpce': 2,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 32212.0,
#   'seniorcare_median_price': 22.75,
#   'median_line_price': 27.87,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 21.25,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18461 FENMORE DETROIT, MI 48235 ',
#   'number': 18461,
#   'street': 'FENMORE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.218319,
#   'latitude': 42.425733,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540300,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 54457.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.87,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '14101 WINTHROP DETROIT, MI 48227 ',
#   'number': 14101,
#   'street': 'WINTHROP',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.199533,
#   'latitude': 42.38946,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542400,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 40568.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
# ...
#   'countyfp': 163,
#   'tractce': 500700,
#   'blkgrpce': 2,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 47292.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 27.87,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '12154 MONTROSE DETROIT, MI 48227 ',
#   'number': 12154,
#   'street': 'MONTROSE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.199768,
#   'latitude': 42.376912,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 545100,
#   'blkgrpce': 2,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 29.93,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19988 PRAIRIE DETROIT, MI 48221 ',
#   'number': 19988,
#   'street': 'PRAIRIE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.145789,
#   'latitude': 42.440082,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 27004.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.35,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '20121 TRINITY DETROIT, MI 48219 ',
#   'number': 20121,
#   'street': 'TRINITY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48219',
#   'longitude': -83.25054,
#   'latitude': 42.439908,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540900,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 59145.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '9582 PREST DETROIT, MI 48227 ',
#   'number': 9582,
#   'street': 'PREST',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.195892,
#   'latitude': 42.366651,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 535300,
#   'blkgrpce': 3,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 34032.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19206 CHARLESTON DETROIT, MI 48203 ',
#   'number': 19206,
#   'street': 'CHARLESTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48203',
#   'longitude': -83.107014,
#   'latitude': 42.433788,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 508000,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 12046.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.35,
#   'petcare_median_price': 17.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '14129 RUTLAND DETROIT, MI 48227 ',
#   'number': 14129,
#   'street': 'RUTLAND',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48227',
#   'longitude': -83.213755,
#   'latitude': 42.389614,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 542500,
#   'blkgrpce': 1,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 63571.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '612 MARSTON DETROIT, MI 48202 ',
#   'number': 612,
#   'street': 'MARSTON',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.06838,
#   'latitude': 42.377582,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511200,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 19883.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.25,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18518 PELKEY DETROIT, MI 48205 ',
#   'number': 18518,
#   'street': 'PELKEY',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.985848,
#   'latitude': 42.431149,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503500,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 39583.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '8284 INDIANA DETROIT, MI 48204 ',
#   'number': 8284,
#   'street': 'INDIANA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48204',
#   'longitude': -83.155084,
#   'latitude': 42.355446,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 534700,
#   'blkgrpce': 1,
#   'median_cleaning_price': 28.9,
#   'median_household_income_17-21': 30039.0,
#   'seniorcare_median_price': 22.0,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18304 STRATHMOOR DETROIT, MI 48235 ',
#   'number': 18304,
#   'street': 'STRATHMOOR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.188317,
#   'latitude': 42.425101,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539600,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 52397.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '2156 PHILIP DETROIT, MI 48215 ',
#   'number': 2156,
#   'street': 'PHILIP',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.946187,
#   'latitude': 42.380327,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 512800,
#   'blkgrpce': 1,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 24886.0,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 28.39,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18631 CHERRYLAWN DETROIT, MI 48221 ',
#   'number': 18631,
#   'street': 'CHERRYLAWN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48221',
#   'longitude': -83.155738,
#   'latitude': 42.428339,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 538600,
#   'blkgrpce': 3,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 58649.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.87,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '19955 WALTHAM DETROIT, MI 48205 ',
#   'number': 19955,
#   'street': 'WALTHAM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48205',
#   'longitude': -82.995581,
#   'latitude': 42.443246,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 503200,
#   'blkgrpce': 2,
#   'median_cleaning_price': 27.87,
#   'median_household_income_17-21': 46027.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '550 SMITH DETROIT, MI 48202 ',
#   'number': 550,
#   'street': 'SMITH',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48202',
#   'longitude': -83.068369,
#   'latitude': 42.375514,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 511200,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 19883.0,
#   'seniorcare_median_price': 22.5,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.25,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18490 LAUDER DETROIT, MI 48235 ',
#   'number': 18490,
#   'street': 'LAUDER',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.192124,
#   'latitude': 42.426576,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 539600,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 47031.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.87,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '18032 FENMORE DETROIT, MI 48235 ',
#   'number': 18032,
#   'street': 'FENMORE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.217629,
#   'latitude': 42.421528,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 540400,
#   'blkgrpce': 2,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': 11639.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 27.87,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '3409 MONTCLAIR DETROIT, MI 48214 ',
#   'number': 3409,
#   'street': 'MONTCLAIR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48214',
#   'longitude': -82.982844,
#   'latitude': 42.374236,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 513900,
#   'blkgrpce': 2,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': 36250.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '11990 RADOM DETROIT, MI 48212 ',
#   'number': 11990,
#   'street': 'RADOM',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48212',
#   'longitude': -83.049898,
#   'latitude': 42.409222,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 510600,
#   'blkgrpce': 3,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 33113.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.38,
#   'petcare_median_price': 17.25,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '14311 CHANDLER PARK DR DETROIT, MI 48213 ',
#   'number': 14311,
#   'street': 'CHANDLER PARK DR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48213',
#   'longitude': -82.963063,
#   'latitude': 42.40048,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502600,
#   'blkgrpce': 3,
#   'median_cleaning_price': 35.1,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 29.42,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '11067 WAYBURN DETROIT, MI 48224 ',
#   'number': 11067,
#   'street': 'WAYBURN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48224',
#   'longitude': -82.955557,
#   'latitude': 42.419145,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 501000,
#   'blkgrpce': 2,
#   'median_cleaning_price': 33.03,
#   'median_household_income_17-21': 42315.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 29.42,
#   'petcare_median_price': 17.75,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '16162 STRATHMOOR DETROIT, MI 48235 ',
#   'number': 16162,
#   'street': 'STRATHMOOR',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.187846,
#   'latitude': 42.410088,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537600,
#   'blkgrpce': 2,
#   'median_cleaning_price': 29.94,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '3145 CHARLEVOIX DETROIT, MI 48207 ',
#   'number': 3145,
#   'street': 'CHARLEVOIX',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48207',
#   'longitude': -83.026192,
#   'latitude': 42.354579,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 516800,
#   'blkgrpce': 1,
#   'median_cleaning_price': 29.42,
#   'median_household_income_17-21': 29500.0,
#   'seniorcare_median_price': 21.75,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '2305 BLAINE DETROIT, MI 48206 ',
#   'number': 2305,
#   'street': 'BLAINE',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48206',
#   'longitude': -83.10237,
#   'latitude': 42.370948,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 533100,
#   'blkgrpce': 2,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': 24479.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '4187 COPLIN DETROIT, MI 48215 ',
#   'number': 4187,
#   'street': 'COPLIN',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48215',
#   'longitude': -82.960567,
#   'latitude': 42.387589,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 502700,
#   'blkgrpce': 3,
#   'median_cleaning_price': 35.61,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 21.5,
#   'median_line_price': 30.97,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '15810 HARTWELL DETROIT, MI 48235 ',
#   'number': 15810,
#   'street': 'HARTWELL',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48235',
#   'longitude': -83.177977,
#   'latitude': 42.407778,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 537000,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.45,
#   'median_household_income_17-21': 54375.0,
#   'seniorcare_median_price': 23.0,
#   'median_line_price': 28.9,
#   'petcare_median_price': 18.0,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89},
#  {'address_full': '2937 BUENA VISTA DETROIT, MI 48238 ',
#   'number': 2937,
#   'street': 'BUENA VISTA',
#   'city': 'DETROIT',
#   'state': 'MI',
#   'zip': '48238',
#   'longitude': -83.124106,
#   'latitude': 42.389424,
#   'statefp': 26,
#   'countyfp': 163,
#   'tractce': 531502,
#   'blkgrpce': 1,
#   'median_cleaning_price': 30.97,
#   'median_household_income_17-21': nan,
#   'seniorcare_median_price': 23.25,
#   'median_line_price': 28.9,
#   'petcare_median_price': 17.5,
#   'spclneeds_median_price': 20.0,
#   'single_child_living_wage': 37.22,
#   'single_nochild_living_wage': 20.42,
#   'couple_child_living_wage': 20.89}]

# %%
## defining a function to call the Care.com api and retrieve the hourly senior care rates and number of hours worked per week for the first 100 caregivers working in a given zip code 

def seniorcare_rates(address):
    headers = {
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'en-US,en;q=0.9',
        # 'cookie': 'JSESSIONID=9EBA7F44BF3067C97971469F83181948; n_vis=dom-gold-prod-webapp-b13.use.dom.carezen.net1722273897345; care_did=e5adc5ac-4ed8-4691-8db4-2096dfb4c7db; FPC=fb31416b-a8df-438c-956d-61c0d392c372; _ga=GA1.1.446140601.1722274031; FPID=FPID2.2.z6MQUgRYtM9hnFqdFq%2FNNQH0j6X8QOCZo4wU5pHUbtM%3D.1722274031; FPAU=1.2.888495742.1722274031; enrollment-session-id=f93ebf6a-3b96-495d-aac0-262ec8f7310d; JSESSIONID=70729B89E4DD1D33C582E1979B226AA6; csc=dom-gold-prod-webapp-b14.use.dom.carezen.net1722530561457; vc=aa112d1a-4a70-483a-97c6-c00c9b0ed338; ROUTE2=d; bm_mi=4DF25BADE412B5D911BA12224C07D4B3~~1; ak_bmsc=52DED96B27C90908E889FE17AAC30339~000000000000000000000000000000~...; FPLC=5d52N1m1ktvqeYG6SwfcP%2FWOmjneSlTQvE137qKHhxJbsP3UTBtB%2BE7vCZc%2F2o%2BTo2eSFqVN59ZNDAHnXRbxJQ3OZHiOrFTBEYfGVYbjpg7sz%2FvCMGM1D4sqs60Icg%3D%3D; frsc=RgO_unCVesmFsT1eYk3YVHnKypObmmEoXmacCCUK_oZFeZRZfxHcS1TnRQx4BBXo-Atsgh0hBFZ2IDOaGlSoQ9A..; owaspToken=9EVD-AZTP-Q6CY-8CCU-FXTY-Z3I0-EEEG-WNO1; cr_wp=eyJ6aXAiOiIxMTIxNiIsImhtIjp0cnVlLCJ2Ijoic2MiLCJtdCI6InMiLCJpc3AiOmZhbHNlLCJsYyI6ImVuLXVzIiwibWkiOjY1MDE2MDkxLCJ1dWlkIjoiNzIzZTZlYzMtYTBkZC00NjY2LTg3NjctMGI3Mzc3YTMxNjhkIiwibiI6Ik1yayBTLiJ9; wordpress_logged_in=1; mt=seeker; oidc-session=...; eps="error standard error"; amp_8bbcdd=e5adc5ac-4ed8-4691-8db4-2096dfb4c7db...1i49ob6e7.1i49oea4h.5.5.a; iterableEmailCampaignId=6246681; iterableTemplateId=8388458; iterableMessageId=39ab2e6ae0624dab9045b14d70980cc0; iterableEndUserId=mrkstat%40gmail.com; lad=ZG9tLWdvbGQtcHJvZC13ZWJhcHAtYjE0LnVzZS5kb20uY2FyZXplbi5uZXQxNzIyNTMwNTYxNDU3; mc=35M7p7y13hPnXdH46fjIpAVJAfvsKRzFKsz73XEzN6SF70FjRpscwnbO1xg5LEdZfouAHUeQFk8yf0%2Bd%2Ferbhg%3D%3D; care_mid=723e6ec3-a0dd-4666-8767-0b7377a3168d; mc_verify=35M7p7y13hPnXdH46fjIpAVJAfvsKRzFKsz73XEzN6SF70FjRpscwnbO1xg5LEdZfouAHUeQFk8yf0*d_erbhg..; sc=qCD2sGJxKGBz2vI*ItIuR5wOjWyhdK93Z6dkZtHHGL0.; csc-session=csc.1.CiBhPnsjKJm5WnSR9JZqISI14l8bzFWIqo_FZwBp2IMXuA.7N4nB74IWVaY9eaZX0voYo_AwByGdtXlC56RVpWjUMY; amp_49ee77=7ZvZ2QTIqPShl-hqk7syXi.NjUwMTYwOTE=..1i49oavgt.1i49of96l.90.n.9n; n_tc=8201%7C2416%7C7579; csc-session-ttl=1726497568; isc=IODv*hpR9Rn4*cpYFDdNqw..; bm_sv=F3BEFE5DB691F59CB988261501E3A1F7~YAAQrJUzuDwjgv6QAQAA5SWIExiCg/IolSeN4nnSjnW/y9o7E7DysruTnbz8G5macsOgq9cQaLJCHnX4FsZCyi8bXmgwEKieV2fXG3hwEZGOjiRHQInHVX6XayJKFOSzMV6el9Y739hY7izd9qgr0GeY66OT14ldZRDgvLYF4Hz0h1OLhCmk83jXgR6VExLM2TMg/RBkdiQiZr83yG5tJSY1NJuHg/enwZ+Kkl8LLI6iwqH40p8PoldgK4DDS/g=~1; _ga_XMJQJVFLTW=GS1.1.1722609342.2.1.1722609575.0.0.350001791; amplitude_id_49ee77491a2b775cf48ecf4a55ce04c5care.com=',
        'owasptoken': 'undefined',
        'priority': 'u=1, i',
        'referer': 'https://www.care.com/visitor/captureSearchBar.do?searchPerformed=true&sitterService=seniorCare&zipCode=11216&milesFromZipCode=1',
        'sec-ch-ua': '"Not)A;Brand";v="99", "Brave";v="127", "Chromium";v="127"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'sec-gpc': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
        'x-care.com-apikey': 'cmtux62opFFZ8Aov8J0aoJ1zRonczZyqP60pTTURdfIx',
        'x-care.com-os': 'Desktop',
        'x-care.com-visitid': 'aa112d1a-4a70-483a-97c6-c00c9b0ed338',
        'x-requested-with': 'XMLHttpRequest',
    }
    
    params = {
        'serviceId': 'SENIRCARE',
        'sitterService': 'seniorCare',
        'zipCode': json.dumps(address),
        'radius': '10',
        'start': '0',
        'max': '100',
        'sortByColumn': 'relevance desc',
        'pageNumber': '1',
    }
    
    response = requests.get('https://www.care.com/platform/spi/search/v2/provider', params=params, headers=headers)
    seniorcare = response.json()
    providers = seniorcare['data']['providerList']
    

    provider_rates = []
    provider_hours = []
    for provider in providers:
        provider_rates.append(provider['hourlyRate'])
        provider_hours.append(provider['weeklyHours'])

    return provider_rates, provider_hours

# %%
def clean_hours(hours):
    hour_range = '(\d+)'
    match = re.findall(hour_range, hours)
    if len(match) > 1:
        cleaned_hours = ((float(match[1]) - float(match[0]))/2) + float(match[0])
    else:
        cleaned_hours = float(match[0])
    return cleaned_hours

# %%
## creating a function to clean the hourly rates. In instances where the rates are presented as a range (for example: $15-25/hr), the midpoint in that range (20) is used.

def clean_rate(rate):
    semiclean = rate.strip('$').strip("/hr").split('-')
    if len(semiclean) > 1:
        cleaned_rate = ((float(semiclean[1]) - float(semiclean[0]))/2) + float(semiclean[0])
    else:
        cleaned_rate = float(semiclean[0])
    return cleaned_rate

# %%
## looping through the Detroit addresses, retreiving the first 100 senior caregivers' hourly rates and weekly hours worked for each address, cleaning the results, and appending them to the address list

for place in tqdm(gigwork_list):
    zip_code = int(place['zip'])
    rate_list = seniorcare_rates(zip_code)[0] ## retrieve the provider_rate list from seniorcare_rates function
    if "N/A" in rate_list:
        rate_list.remove("N/A") ## remove all "N/A" values from the provider rate list
    dirty_hour_list = seniorcare_rates(zip_code)[1] ## retrieve the provider_hours list from seniorcare_rates function
    semiclean_hours = [i for i in dirty_hour_list if i] ## remove all missing values from the list
    pretty_rate = []
    pretty_hours = []
    for rate in rate_list:
        pretty_rate.append(clean_rate(rate)) ## clean the hourly rates, turning them into floats
    for hours in semiclean_hours:
        pretty_hours.append(clean_hours(hours)) ## clean the weekly hours, turning them into floats
    median_price = statistics.median(pretty_rate) ## calculate the median rate for providers in the given zip code
    median_hours = statistics.median(pretty_hours) ## calculate the median weekly hours worked by providers in the given zip code 
    place['seniorcare_median_price'] = median_price
    place['seniorcare_median_hours'] = median_hours
    time.sleep(1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [22:25<00:00,  6.73s/it]

# %%
## converting the list with the additional information back into a dataframe

gig_prices = pd.DataFrame(gigwork_list)
gig_prices
# Out:
#                             address_full  number       street     city state  \
# 0         748 DUNKIRK DETROIT, MI 48217      748      DUNKIRK  DETROIT    MI
# 1        1558 CALVERT DETROIT, MI 48206     1558      CALVERT  DETROIT    MI
# 2        8083 NORMILE DETROIT, MI 48204     8083      NORMILE  DETROIT    MI
# 3        4054 RICHTON DETROIT, MI 48204     4054      RICHTON  DETROIT    MI
# 4         8317 PENROD DETROIT, MI 48228     8317       PENROD  DETROIT    MI
# ..                                   ...     ...          ...      ...   ...
# 195   3145 CHARLEVOIX DETROIT, MI 48207     3145   CHARLEVOIX  DETROIT    MI
# 196       2305 BLAINE DETROIT, MI 48206     2305       BLAINE  DETROIT    MI
# 197       4187 COPLIN DETROIT, MI 48215     4187       COPLIN  DETROIT    MI
# 198    15810 HARTWELL DETROIT, MI 48235    15810     HARTWELL  DETROIT    MI
# 199  2937 BUENA VISTA DETROIT, MI 48238     2937  BUENA VISTA  DETROIT    MI
#
#        zip  longitude   latitude  statefp  countyfp  ...  \
# 0    48217 -83.150601  42.286192       26       163  ...
# 1    48206 -83.100993  42.384252       26       163  ...
# 2    48204 -83.158999  42.352950       26       163  ...
# 3    48204 -83.130003  42.381745       26       163  ...
# 4    48228 -83.220193  42.354021       26       163  ...
# ..     ...        ...        ...      ...       ...  ...
# 195  48207 -83.026192  42.354579       26       163  ...
# 196  48206 -83.102370  42.370948       26       163  ...
# 197  48215 -82.960567  42.387589       26       163  ...
# 198  48235 -83.177977  42.407778       26       163  ...
# 199  48238 -83.124106  42.389424       26       163  ...
#
#      median_cleaning_price  median_household_income_17-21  \
# 0                    27.87                        18750.0
# 1                    30.97                        27197.0
# 2                    27.87                        36571.0
# 3                    30.97                        53333.0
# 4                    27.87                        23315.0
# ..                     ...                            ...
# 195                  29.42                        29500.0
# 196                  30.97                        24479.0
# 197                  35.61                            NaN
# 198                  30.45                        54375.0
# 199                  30.97                            NaN
#
#      seniorcare_median_price  median_line_price  petcare_median_price  \
# 0                      21.75              25.80                  17.5
# 1                      23.00              28.38                  17.5
# 2                      22.50              30.97                  17.5
# 3                      22.50              28.90                  17.5
# 4                      22.50              28.90                  17.5
# ..                       ...                ...                   ...
# 195                    22.75              28.90                  17.5
# 196                    23.00              28.90                  17.5
# 197                    21.50              30.97                  17.5
# 198                    24.00              28.90                  18.0
# 199                    23.00              28.90                  17.5
#
#      spclneeds_median_price  single_child_living_wage  \
# 0                     20.00                     37.22
# 1                     20.00                     37.22
# 2                     20.00                     37.22
# 3                     20.00                     37.22
# 4                     19.25                     37.22
# ..                      ...                       ...
# 195                   20.00                     37.22
# 196                   20.00                     37.22
# 197                   20.00                     37.22
# 198                   20.00                     37.22
# 199                   20.00                     37.22
#
#      single_nochild_living_wage  couple_child_living_wage  \
# 0                         20.42                     20.89
# 1                         20.42                     20.89
# 2                         20.42                     20.89
# 3                         20.42                     20.89
# 4                         20.42                     20.89
# ..                          ...                       ...
# 195                       20.42                     20.89
# 196                       20.42                     20.89
# 197                       20.42                     20.89
# 198                       20.42                     20.89
# 199                       20.42                     20.89
#
#      seniorcare_median_hours
# 0                      30.00
# 1                      30.00
# 2                      29.25
# 3                      29.25
# 4                      30.00
# ..                       ...
# 195                    30.00
# 196                    30.00
# 197                    30.00
# 198                    28.00
# 199                    29.25
#
# [200 rows x 22 columns]

# %%
## dropping the unneccessary index column

gig_prices = gig_prices.drop(columns=['Unnamed: 0'])

# %%
gig_prices.head()
# Out:
#                       address_full  number   street     city state    zip  \
# 0   748 DUNKIRK DETROIT, MI 48217      748  DUNKIRK  DETROIT    MI  48217
# 1  1558 CALVERT DETROIT, MI 48206     1558  CALVERT  DETROIT    MI  48206
# 2  8083 NORMILE DETROIT, MI 48204     8083  NORMILE  DETROIT    MI  48204
# 3  4054 RICHTON DETROIT, MI 48204     4054  RICHTON  DETROIT    MI  48204
# 4   8317 PENROD DETROIT, MI 48228     8317   PENROD  DETROIT    MI  48228
#
#    longitude   latitude  statefp  countyfp  tractce  blkgrpce  \
# 0 -83.150601  42.286192       26       163   524500         2
# 1 -83.100993  42.384252       26       163   531900         1
# 2 -83.158999  42.352950       26       163   535600         4
# 3 -83.130003  42.381745       26       163   530900         2
# 4 -83.220193  42.354021       26       163   546000         2
#
#    median_cleaning_price  median_household_income_17-21  \
# 0                  27.87                        18750.0
# 1                  30.97                        27197.0
# 2                  27.87                        36571.0
# 3                  30.97                        53333.0
# 4                  27.87                        23315.0
#
#    seniorcare_median_price
# 0                     20.5
# 1                     23.0
# 2                     22.0
# 3                     22.0
# 4                     22.5

# %%
gig_prices.to_csv("gigwork_rates_seniorhours.csv", index=False)
